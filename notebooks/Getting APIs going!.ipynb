# %% [markdown]
# ## WEB API Scraper using www.page2api.com
# ## SCRAPING Job Review Data from Glassdoor

# %% [markdown]
# The provided code is making a POST request to the Page2API service to scrape data from the Glassdoor website. Here's a breakdown of the code:
#
# The requests and json modules are imported.
#
# api_url is set to the URL of the Page2API service.
#
# The payload dictionary contains the parameters for the API request. It includes the following:
#
# api_key: The API key provided by Page2API.
#
# premium_proxy: The premium proxy location set to 'us'.
#
# real_browser: A boolean value indicating whether a real browser should be used for scraping (set to True).
#
# javascript: A boolean value indicating whether JavaScript should be executed during scraping (set to False).
#
# batch: A sub-dictionary specifying the batch scraping configuration. It includes the following:
# urls: The URL(s) to be scraped.
#
# concurrency: The number of concurrent requests to be made (set to 1).
#
# merge_results: A boolean value indicating whether to merge the results into a single response (set to True).
#
# parse: A sub-dictionary specifying the parsing configuration. It includes the following:
#
# reviews: A list containing a single item (a dictionary) with instructions on how to parse the reviews. It specifies various CSS selectors to extract data such as review titles, author information, ratings, pros, cons, and helpful counts.
#
# The headers dictionary specifies the content type and accept headers for the API request.
#
# A POST request is made to the api_url using requests.post(). The data parameter contains the JSON-encoded payload, and the headers are included.
#
# The response is stored in the response variable.
#
# The response text is loaded into a dictionary using json.loads() and stored in the result variable.

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 1].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %% [markdown]
# ###  import to pandas

# %%
import pandas as pd
df = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df
# Out:
#                                         title
# 0                         generell ist es gut  \
# 1                           Guter Arbeitgeber
# 2    Umtrukturierung hat Teams kaputt gemacht
# 3                                         Gut
# 4                                       Super
# 5      Spannende Aufgabe in einem tollen Team
# 6                         Toller Arbeitsgeber
# 7                          Klasse Arbeitgeber
# 8                                   Bewertung
# 9                           Guter Arbeitgeber
# 10                   Jammern auf hohem Niveau
# 11               Sehr sehr schwache Vergütung
# 12                                Lernerfolge
# 13                 Guter, solider Arbeitgeben
# 14                  Tolle Firma für Studenten
# 15                                       BASF
# 16               Schlechteste Berufserfahrung
# 17                Großkonzern als Arbeitgeber
# 18      Flexibilität aber schlechte Bezahlung
# 19              Bester Arbeitgeber, Sehr Fair
# 20                       Angebliche Übernahme
# 21                                      Super
# 22                                 It depends
# 23                         Spannende Aufgaben
# 24                               Arbeitsplatz
# 25                             Overall review
# 26                           Hat Spaß gemacht
# 27                                        Top
# 28                         Toller Arbeitgeber
# 29                                BASF Berlin
# 30                                  Very good
# 31                       Viel Schein als Sein
# 32                        Great place to work
# 33                                       Toll
# 34                      Optimale Verhältnisse
# 35                       BASF Services Europe
# 36                         Guter Einstiegsjob
# 37                           Werkstudent BASF
# 38            Regulatorische Produktbetreuung
# 39                                        Gut
# 40  Einarbeitung gut - danach flach Lernkurve
# 41                                   sehr gut
# 42        Open and Super-friendly environment
# 43                                          /
# 44                                       basf
# 45                    Great starting position
# 46                                     review
# 47                   Werkstudent Ludwigshafen
# 48                          Guter Arbeitgeber
# 49                            Kostenreduktion
#
#                                           author_info rating
# 0                         12. Apr. 2023 - Werkstudent    5,0  \
# 1              29. Apr. 2023 - Senior DevOps Engineer    3,0
# 2           26. Apr. 2023 - Finance Senior Specialist    2,0
# 3                        5. Apr. 2023 - HR Generalist    5,0
# 4                    31. März 2023 - Qualitätsmanager    5,0
# 5                  16. März 2023 - Head of Innovation    5,0
# 6   23. März 2023 - Elektroniker für Prozessleitte...    5,0
# 7                    7. März 2023 - Software Engineer    5,0
# 8                           10. März 2023 - Ingenieur    4,0
# 9                         20. Feb. 2023 - Laborleiter    5,0
# 10                        14. Feb. 2023 - Teamleitung    2,0
# 11                            3. Nov. 2022 - Abfüller    1,0
# 12                     15. Feb. 2023 - Senior Officer    4,0
# 13            26. Jan. 2023 - Industriemeister Metall    4,0
# 14                          16. Jan. 2023 - Diplomand    5,0
# 15                    15. Jan. 2023 - Laborteamleiter    4,0
# 16                         28. Dez. 2022 - Praktikant    1,0
# 17               15. Dez. 2022 - Freight Cost Manager    4,0
# 18           4. Nov. 2022 - Kaufmännische Angestellte    3,0
# 19                            6. Nov. 2022 - Director    5,0
# 20                     21. Nov. 2022 - Digital Expert    3,0
# 21                26. Nov. 2022 - Engineering Manager    5,0
# 22          18. Apr. 2022 - Team Lead Web Development    3,0
# 23        1. Nov. 2022 - Business Development Manager    2,0
# 24                       5. Nov. 2022 - Praktikant/in    5,0
# 25                   19. Sept. 2022 - Cost Controller    3,0
# 26                        20. Okt. 2022 - HR Assitant    4,0
# 27                          15. Okt. 2022 - Chemikant    4,0
# 28                           7. Okt. 2022 - Chemikant    5,0
# 29              18. Sept. 2022 - Anonymer Mitarbeiter    4,0
# 30   2. Sept. 2022 - Senior Specialist Digitalization    5,0
# 31                  26. Aug. 2022 - Senior Accountant    3,0
# 32               18. Juli 2022 - Senior Cost Engineer    5,0
# 33                          20. Aug. 2022 - Chemikant    5,0
# 34        3. Aug. 2022 - Projekt-/Verfahrensingenieur    5,0
# 35                     17. Aug. 2022 - Senior Manager    4,0
# 36                  28. Juli 2022 - Senior Controller    4,0
# 37                        29. Juli 2022 - Werkstudent    5,0
# 38                 2. Juli 2022 - Product Stewardship    4,0
# 39        15. Juli 2022 - Customer Service Specialist    3,0
# 40                         30. Mai 2022 - Werkstudent    3,0
# 41                     8. Juli 2022 - Bereichsleitung    5,0
# 42                 12. Apr. 2022 - Collection Officer    5,0
# 43              5. Juli 2022 - Posdoctoral Researcher    2,0
# 44                           3. Juli 2022 - Chemikant    3,0
# 45         8. Apr. 2022 - Project Engineering Manager    4,0
# 46                     10. Juli 2022 - VAT Accountant    1,0
# 47                          4. Mai 2022 - Werkstudent    4,0
# 48                     6. Mai 2022 - Systems Engineer    4,0
# 49         12. Mai 2022 - Head of Business Management    3,0
#
#                                                  pros
# 0   Attraktive Aufgaben, flexible Arbeitszeit und ...  \
# 1   Sicherer Arbeitsplatz, gute Arbeitsauslastung,...
# 2   sicherer Arbeitsplatz mit viel Entfaltungsmögl...
# 3          Gehalt sowie die Kollegen und Vorgesetzten
# 4              Tolle Firma hab immer gerne gearbeitet
# 5   Netzwerk an tollen Kollegen Diverse Teams, mit...
# 6   Fairer Arbeitsgeber, mit tollen Perspektiven u...
# 7              Sehr modern in der Softwareentwicklung
# 8         -spannender Arbeitsplatz und nette kollegen
# 9                Große Firma mit vielen Möglichkeiten
# 10  Gehalt Work-Life-Balance Flexibilität Sicherhe...
# 11  Pros gibt es nur für Leute die sich keine Ziel...
# 12                     Die Lernerfolge sind sehr gut.
# 13  - Gehalt - Sicherheit - Entwicklungsmöglichkei...
# 14  Gute Betreuung durch erfahrene Mitarbeiter, Ge...
# 15  -Großes Unternehmen -Gute Kantine -Vielfältige...
# 16              -sicherer Job - bekanntes Unternehmen
# 17  Flexible Arbeitszeit,Home Office,Möglichkeit i...
# 18  Man kann flexibel arbeiten , auch im Home Offi...
# 19  Hohes Gehalt, Flexible Arbeitszeiten, Niedrige...
# 20  gutes Einkommen starkes Teamwork stabiles Unte...
# 21                          Job passt perfekt zu mir.
# 22  BASF is huge. If you aim for career and you're...
# 23  - spannende Aufgaben - gute Gehaltssteigerung ...
# 24               Gute Vernetzung, sehr gute Eindrücke
# 25  One of the biggest companies in Germany. Engli...
# 26         - Stabiler Laden - geregelte Arbeitszeiten
# 27     Grosses Unternehmen viele Betriebe. Guter Lohn
# 28  Pünktliche Zahlung tolle Mitarbeiter Freude an...
# 29                      Perfect for first job seekers
# 30  Good work-life balance Company culture Collegi...
# 31  Internationales Umfeld. Viele Entwicklungsmögl...
# 32  Solid company with many options for career dev...
# 33  Toller Arbeitgeber, Viele weiter - entwicklung...
# 34  Positive Punkte: Gehalt ist in Ordnung Arbeits...
# 35   Good Work environment, development opportunities
# 36  Flexibilität, nette Kollegen und auch Führungs...
# 37      Nette und freundliche Kollegen Gute Bezahlung
# 38  Gutes Gehalt, dank Corona relativ flexible Arb...
# 39                  Gehalt kommt pünktlich aufs Konto
# 40  super nettes Team, viele Aufgaben in einem int...
# 41  eine nachhaltiges und zukunftsträchtiges Unter...
# 42  Wie ein Koloss, den ich irgendwo als sehr lang...
# 43                           Nice people to work with
# 44               urlaubs geld lohn gehalt urlaubsgeld
# 45  - You can steer your career to a high degree, ...
# 46                         the experience you can get
# 47  Gute Vergütung und Nette Kollegen. Eigenes Zei...
# 48  BASF ist das größte Chemie Unternehmen und seh...
# 49  A nice multinational atmosphere especially in ...
#
#                                                  cons
# 0                     Langes Warten auf neue Aufgaben
# 1   Schlechte Karrieremöglichkeiten als Experte, v...
# 2            Gehalt im Vergleich zum Workload unfair.
# 3                    Umzug nach Berlin war vorgesehen
# 4                    Morgens so früh aufstehen müssen
# 5    Anspruchsvolle Aufgabe Viele Themen gleichzeitig
# 6         Chemie Industrie ist nicht jedermanns Sache
# 7   Teilweise alte Stukturen und entsprechende Kul...
# 8         - langsame Prozesse und komplexe strukturen
# 9                   Nicht so flexibel wie Mittelstand
# 10  Schwere Karrierechancen Top-Down Management St...
# 11  - sehr sehr sehr geringes Gehalt, kann man sic...
# 12  Die Gesamtvergütung ist nicht in allen Bereich...
# 13  - Hierarchie - Nicht alle Jobs sind finanziell...
# 14  Unter Umständen kann das arbeiten zwischenmens...
# 15       -Sehr bürokratisch -Langsam bei Innovationen
# 16  - alte konservative Strukturen - Greenwashing ...
# 17  Gehalt , hohe Arbeitsbelastung, Karrierewege h...
# 18  Die Bezahlung ist sehr sehr schlecht. Habe des...
# 19  Ludwigshafen ist eine sehr hässliche Stadt. Ma...
# 20  versprechen auf Übernahme angeblich wegen Gask...
# 21        Viele Leute beschweren sich über Lappalien.
# 22  There's a huge difference between BASF Berlin ...
# 23  - Vertrauensarbeitszeit für fast alle Mitarbei...
# 24  Schwache Kommunikation zwischen verschiedenen ...
# 25    It doesn't have that cool start-up environment.
# 26  - schlechte Aufstiegs Möglichkeiten Thema Karr...
# 27                      Es gibt keine vlt mehr Urlaub
# 28                     Es gibt keine Kontras für mich
# 29         Compensation should be definitely improved
# 30  Rigid structure Hierarchy Intransparent criter...
# 31  Gehalt. Führungsleute werden dazu geschult, di...
# 32  Very hard to change status quo of many interna...
# 33               es gibt keine - dumme 5 worte regelt
# 34  Negative Punkte: -Großes Unternehmen und dadur...
# 35         Salary too low, sometimes too bureaucratic
# 36  geringes Gehalt für viel eintönige Arbeit, häu...
# 37  Sehr viele sich wiederholende Routineaufgaben,...
# 38  Leider muss man doch sehr um gerechte Bezahlun...
# 39        lange Entscheidungswege und wenig Spielraum
# 40  man wird bei vielem alleine gelassen, Onboardi...
# 41                      fallen mir wirklich keine ein
# 42  Nach drei Monaten hat mich noch nichts negativ...
# 43                  Poor work life balance in general
# 44                   mit arbeiter und arbeits zeiteen
# 45  - Depending on the project you get, repetitive...
# 46                         the salary is not the best
# 47  Einarbeitung war nicht wirklich da. Kein große...
# 48          Etwas konservqtiv und schwer sufzusteigen
# 49      It’s not any more cost reduction, but „cheap”

# %% [markdown]
# ### changing the Pages manually
# Change is made at the url field @ P[1, 50]

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 2].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df4 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df4
# Out:
#                                                  title
# 0                                                Super  \
# 1    Verbesserungsvorschläge für eine noch bessere ...
# 2                        Gutes Gehalt, flexible Zeiten
# 3                          Nettes Team, gute Erfahrung
# 4                           Führen durch Intransparenz
# ..                                                 ...
# 153                                   Great internship
# 154                                    Top Unternehmen
# 155                                        cobntroller
# 156                                    Product Manager
# 157                                         Gute Sache
#
#                                    author_info rating
# 0    5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1             20. Mai 2023 - Anlagenmechaniker    4,0
# 2           23. Mai 2023 - Industriemechaniker    4,0
# 3                   16. Mai 2023 - Werkstudent    3,0
# 4                      5. Mai 2023 - Ingenieur    2,0
# ..                                         ...    ...
# 153                     23. Jan. 2022 - Intern    5,0
# 154                   22. Juli 2021 - Operator    5,0
# 155                  26. Mai 2021 - Controller    5,0
# 156           10. Sept. 2017 - Product Manager    3,0
# 157                 28. Feb. 2020 - Accountant    3,0
#
#                                                   pros
# 0    Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1    Globale Präsenz: BASF ist ein multinationaler ...
# 2    Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3    Team, Einblicke, Support... Es hat Spaß gemach...
# 4    Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                 ...
# 153                 Learned a lot, staff are very nice
# 154  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 155      work life balance, arbeitszeit, lernfähigkeit
# 156  Großunternehmen, im Allgemeinen sicherer Arbei...
# 157          Kommunikation aktiv statisch proaktiv neu
#
#                                                   cons
# 0            Ein riesiger laden etwas zu groß für mich
# 1    Größe und Komplexität: Als globaler Konzern mi...
# 2    Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3    Die Organisation hat zeitweilig zu wünschen üb...
# 4    Management, Führungskräfte und das gesamte Sys...
# ..                                                 ...
# 153               Non to speak of, very friendly staff
# 154          -Zu wenig Personal -Zu kurze Einarbeitung
# 155  gehalt, wechselgedanken, entwicklung, neue auf...
# 156  Als übernommener Mitarbeiter sah ich viele mei...
# 157           Handling relax brauchbar neu fortschritt
#
# [158 rows x 5 columns]

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 6].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df5 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df5
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# 5            Umtrukturierung hat Teams kaputt gemacht
# 6                                   Guter Arbeitgeber
# 7                                 generell ist es gut
# 8                                                 Gut
# 9                                               Super
# 10                                Verbesserungswürdig
# 11             Seriöser Arbeitgeber - wenige Benefits
# 12                                                Gut
# 13                        Ein wunderbares Unternehmen
# 14                                  Junior Controller
# 15                                              keine
# 16                Bequem aber nicht Zukunftsgerichtet
# 17                             Good work-life balance
# 18                                                  -
# 19                                         Alles Top!
# 20                                  Guter Arbeitgeber
# 21                                 Tolles Unternehmen
# 22                                    Top Arbeitgeber
# 23                      Stellenbeschreibung unpassend
# 24                                           Sehr gut
# 25                                          Alles gut
# 26                       vertrauensvoller Arbeitgeber
# 27                                       Super Firma!
# 28                        Top-Firma mit Verantwortung
# 29                                                  *
# 30                                               Toll
# 31                                          Alles gut
# 32                                             Klasse
# 33                                               BASF
# 34                                  Guter Arbeitgeber
# 35                                    Gute Anstellung
# 36                                  Aniliner forever!
# 37                                                Gut
# 38                                                Gut
# 39                                     Prima Nebenjob
# 40                                           Sehr gut
# 41                                    Super Zufrieden
# 42                                      Senior Expert
# 43                                  Gutes Unternehmen
# 44        Hohe Komplexität im herausfordernden Umfeld
# 45      Beste Möglichkeiten um Erfahrungen zu sammeln
# 46                                           Vielfalt
# 47                                       FERIENHELFER
# 48                         Projektmanager bei BASF SE
# 49                  Noch immer der größte Arbeitgeber
# 50                                   Schlecht Bezahlt
# 51                                               Gute
# 52  Sicherer Job, da Personalbestand am unteren Li...
# 53                                   Great internship
# 54                                    Top Unternehmen
# 55                                        cobntroller
# 56                                    Product Manager
# 57                                         Gute Sache
#
#                                           author_info rating
# 0           5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1                    20. Mai 2023 - Anlagenmechaniker    4,0
# 2                  23. Mai 2023 - Industriemechaniker    4,0
# 3                          16. Mai 2023 - Werkstudent    3,0
# 4                             5. Mai 2023 - Ingenieur    2,0
# 5           26. Apr. 2023 - Finance Senior Specialist    2,0
# 6              29. Apr. 2023 - Senior DevOps Engineer    3,0
# 7                         12. Apr. 2023 - Werkstudent    5,0
# 8                        5. Apr. 2023 - HR Generalist    5,0
# 9                    31. März 2023 - Qualitätsmanager    5,0
# 10         1. März 2022 - Senior Reporting Specialist    3,0
# 11              10. März 2022 - Studentische Aushilfe    3,0
# 12         13. März 2022 - Human Resources Generalist    3,0
# 13                           1. Feb. 2022 - Masterand    5,0
# 14                   4. März 2022 - Junior Controller    2,0
# 15                       7. Feb. 2022 - Praktikant/in    5,0
# 16                      1. Feb. 2022 - Chemielaborant    4,0
# 17               22. Jan. 2022 - Financial Controller    4,0
# 18                     26. Jan. 2022 - Prozessmanager    4,0
# 19    17. Jan. 2022 - SAP Security and GRC Consultant    5,0
# 20                            25. Juni 2021 - Monteur    4,0
# 21                             25. Mai 2021 - Trainee    4,0
# 22  16. Juni 2021 - HR Business Partner Talentmana...    5,0
# 23               27. Apr. 2021 - Wirtschaftsingenieur    2,0
# 24                      21. Juni 2021 - Praktikant/in    5,0
# 25                            9. Juni 2021 - Engineer    4,0
# 26                   27. Mai 2021 - Industriekaufmann    5,0
# 27              30. Mai 2021 - Produktionsmitarbeiter    5,0
# 28                        29. Apr. 2021 - Bachelorand    5,0
# 29                  7. Juni 2021 - Payroll Specialist    2,0
# 30                         24. Nov. 2020 - HR Manager    4,0
# 31                 9. Nov. 2020 - Procurement Manager    4,0
# 32            12. Nov. 2020 - Bereichsleiter Logistik    5,0
# 33                  22. Nov. 2020 - Anlagenmechaniker    5,0
# 34                      20. Okt. 2020 - Feuerwehrmann    5,0
# 35                          11. Okt. 2020 - ingénieur    4,0
# 36                       26. Sept. 2020 - Laborleiter    5,0
# 37                           6. Jan. 2021 - Techniker    1,0
# 38  5. Okt. 2020 - Contract and Tax Reporting Manager    4,0
# 39                        9. Sept. 2020 - Werkstudent    4,0
# 40          19. März 2020 - General Ledger Accountant    4,0
# 41                    15. Sept. 2015 - Phyisklaborant    5,0
# 42        8. Mai 2019 - Digital Transformation Office    3,0
# 43                          4. Dez. 2019 - Buchhalter    5,0
# 44                16. Mai 2017 - Anonymer Mitarbeiter    4,0
# 45                        30. Jan. 2017 - Werkstudent    4,0
# 46      6. Aug. 2017 - Accountant Accounts Receivable    3,0
# 47                                     4. Dez. 2017 -    5,0
# 48                   3. Aug. 2018 - Projektmanager/in    5,0
# 49               22. März 2017 - Anonymer Mitarbeiter    4,0
# 50               22. Feb. 2020 - Anonymer Mitarbeiter    1,0
# 51               18. Juni 2022 - Anonymer Mitarbeiter    4,0
# 52   7. Jan. 2022 - Chemielaborant Qualitätskontrolle    3,0
# 53                             23. Jan. 2022 - Intern    5,0
# 54                           22. Juli 2021 - Operator    5,0
# 55                          26. Mai 2021 - Controller    5,0
# 56                   10. Sept. 2017 - Product Manager    3,0
# 57                         28. Feb. 2020 - Accountant    3,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# 5   sicherer Arbeitsplatz mit viel Entfaltungsmögl...
# 6   Sicherer Arbeitsplatz, gute Arbeitsauslastung,...
# 7   Attraktive Aufgaben, flexible Arbeitszeit und ...
# 8          Gehalt sowie die Kollegen und Vorgesetzten
# 9              Tolle Firma hab immer gerne gearbeitet
# 10  Man kann viel Erfahrung sammeln Die Sport Mitg...
# 11  Rücksichtnahme auf das Studium Flexible Arbeit...
# 12           Es gab viel Home office und Flexibilität
# 13  Man hat die Möglichkeit, sich mit spannenden A...
# 14  Flexibility Good location Nice management and ...
# 15  tolle atmo, und die Mitarbeiter wird sehr gut ...
# 16  Gehalt Absicherung Urlaub Gutes Team Relativ v...
# 17  Mobile working, even remote working, which con...
# 18  Interesting projects, very competent colleague...
# 19  Prima Herausforderungen, nette Kollegen und Ku...
# 20             Gutes Gehalt und gute Bedingung. Tarif
# 21  Soziales Unternehmen, das spannende Aufgaben v...
# 22  Gute Möglichkeiten im Unternehmen verschiedene...
# 23  nette Kollegen im Team, gegenseitige Unterstüt...
# 24       Nette Kollege, Gute atmosphäere, Arbeitklime
# 25                   Alles gut, Arbeit ist in Ordnung
# 26  Dankt einem den Einsatz ehrlich und unterstütz...
# 27           Es wird alles für den Mitarbeiter getan!
# 28  Absolut Arbeitnehmerfreundlich, Förderung bei ...
# 29             Lage, Kollegen und der renomierte Name
# 30  Es gab viele Entwicklungsmöglichkeiten und all...
# 31           Ich bin noch recht neu und warte noch ab
# 32                            Alles gut bei der BASF.
# 33  faires Gehalt Firmenwagen ausreichende Schutzv...
# 34                 Gutes Gehalt und guter Arbeitgeber
# 35  Nicht nur Gehalt, sondern auch Extras (Essen, ...
# 36  Sehr sicheres Arbeitsumfeld mit vielen Entfalt...
# 37                      Sehr gute Fima mit gute Image
# 38                   Gutes Geld bei guter Arbeitszeit
# 39  Hohes Gehalt, nette Kollegen, interessante Tät...
# 40  Teamgeist, verschiedene Nationalitäten unter e...
# 41  es wird viel für Mitarbeiter gemacht. Super at...
# 42  In Sachen Arbeitsplatzsicherheit und Zusatzlei...
# 43  Super Mitarbeiter und Team Leiter , flexible A...
# 44  Betriebs-Kita, Aktienprogramm für alle Mitarbe...
# 45  Bereichsübergreifendes Denken und Handeln, vie...
# 46  Kollegen aus aller Welt, vielfältige Aufgaben,...
# 47  Mit der Tätigkeit verschafft man sich einen gu...
# 48  Innovative, arbeitnehmerfreundliche, weltweit ...
# 49  Viele verschiedene Menschen viele verschiedene...
# 50                          es gibt Chancen zu lernen
# 51  Tolle Lernkurve mit nett leute und attractive ...
# 52  Hohe Sicherheitskultur mit regelmäßigen Schulu...
# 53                 Learned a lot, staff are very nice
# 54  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 55      work life balance, arbeitszeit, lernfähigkeit
# 56  Großunternehmen, im Allgemeinen sicherer Arbei...
# 57          Kommunikation aktiv statisch proaktiv neu
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# 5            Gehalt im Vergleich zum Workload unfair.
# 6   Schlechte Karrieremöglichkeiten als Experte, v...
# 7                     Langes Warten auf neue Aufgaben
# 8                    Umzug nach Berlin war vorgesehen
# 9                    Morgens so früh aufstehen müssen
# 10  Das Gehalt Die "Kantine" Andere Benefits (Akti...
# 11  Starre Arbeitsprozesse mit wenig Handlungsspie...
# 12                        Das Gehalt ist sehr niedrig
# 13  Während der Pandemie mein Praktikum und Master...
# 14      Low pay Less transparent Lots of cost cutting
# 15  Manchmal bei der Plannung wird nicht so viel d...
# 16  Unflexibel Altbacken Technologisch Rückständig...
# 17                     a little high rate of turnover
# 18  Slow career progression, slow decision making ...
# 19                 Es sind mir keine Kontras bekannt.
# 20             Guter AG- eigentlich keine, siehe oben
# 21                Man ist halt nicht Ludwigshafen ...
# 22          Durch Matrixstruktur zum Teil etwas träge
# 23  inkompetente Führungskraft, Stellenausschreibu...
# 24                     Ich hab keine Nachteil gesehen
# 25               Nichts, manchmal gibt es viel Stress
# 26         Manchmal kommt es zur Überbelastung der MA
# 27      Nichts wesentliches, was man kritisieren kann
# 28  Probleme teilweise unnötig kompliziert, es wir...
# 29  Entwickmungsmöglichkeiten, Gehalt und die ange...
# 30                        Das Gehalt ist sehr niedrig
# 31  bisher noch keine, ich muss noch alles kennenl...
# 32                    Keine!Es ist alles gut bei BASF
# 33                   an manchen Orten relativ dreckig
# 34     Viele Schichten die im Jahr abgeleistet werden
# 35  Teilweise schwierige Arbeitsatmosphäre, sonst ...
# 36  Teilweise recht konservative Strukturen im Unt...
# 37                     Kann besser werden allen ebene
# 38  Standort ist schrecklich ludwigshafen ist schr...
# 39  Wenig Kommunikation, hoher workload, wenig ver...
# 40  Gehalt, Wissentransfer, Unfähigkeit von manche...
# 41  Kastensystem. Was auf dem Schein steht zählt b...
# 42  Eigene Kreativität und auch Transparenz der Ma...
# 43  Gehalt könnte höher sein, bei anderen Firmen z...
# 44  Komplexe Organisation, lange Entscheidungswege...
# 45  ein Weiterkommen im Unternehmen ist meist am V...
# 46  übertriebene Hierachien, Teamleiter gegen stat...
# 47     Man sollte sich an die Arbeitszeiten gewöhnen.
# 48                 durch die Größe etwas schwerfällig
# 49  sehr langsame Abwicklung von Vorgängen man ist...
# 50                   Wenig bezahlt und zu viel stress
# 51                Nicht so viel freiheit/ möglichkeit
# 52  Demografischer Wandel am Standort zu spät entg...
# 53               Non to speak of, very friendly staff
# 54          -Zu wenig Personal -Zu kurze Einarbeitung
# 55  gehalt, wechselgedanken, entwicklung, neue auf...
# 56  Als übernommener Mitarbeiter sah ich viele mei...
# 57           Handling relax brauchbar neu fortschritt

# %%
##tocvs

# %%
dfcomplete=pd.concat([df4, df5], axis=0, ignore_index=True)
dfcomplete.drop_duplicates()
dfcomplete
# Out:
#                                                  title
# 0                                                Super  \
# 1    Verbesserungsvorschläge für eine noch bessere ...
# 2                        Gutes Gehalt, flexible Zeiten
# 3                          Nettes Team, gute Erfahrung
# 4                           Führen durch Intransparenz
# ..                                                 ...
# 211                                   Great internship
# 212                                    Top Unternehmen
# 213                                        cobntroller
# 214                                    Product Manager
# 215                                         Gute Sache
#
#                                    author_info rating
# 0    5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1             20. Mai 2023 - Anlagenmechaniker    4,0
# 2           23. Mai 2023 - Industriemechaniker    4,0
# 3                   16. Mai 2023 - Werkstudent    3,0
# 4                      5. Mai 2023 - Ingenieur    2,0
# ..                                         ...    ...
# 211                     23. Jan. 2022 - Intern    5,0
# 212                   22. Juli 2021 - Operator    5,0
# 213                  26. Mai 2021 - Controller    5,0
# 214           10. Sept. 2017 - Product Manager    3,0
# 215                 28. Feb. 2020 - Accountant    3,0
#
#                                                   pros
# 0    Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1    Globale Präsenz: BASF ist ein multinationaler ...
# 2    Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3    Team, Einblicke, Support... Es hat Spaß gemach...
# 4    Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                 ...
# 211                 Learned a lot, staff are very nice
# 212  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 213      work life balance, arbeitszeit, lernfähigkeit
# 214  Großunternehmen, im Allgemeinen sicherer Arbei...
# 215          Kommunikation aktiv statisch proaktiv neu
#
#                                                   cons
# 0            Ein riesiger laden etwas zu groß für mich
# 1    Größe und Komplexität: Als globaler Konzern mi...
# 2    Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3    Die Organisation hat zeitweilig zu wünschen üb...
# 4    Management, Führungskräfte und das gesamte Sys...
# ..                                                 ...
# 211               Non to speak of, very friendly staff
# 212          -Zu wenig Personal -Zu kurze Einarbeitung
# 213  gehalt, wechselgedanken, entwicklung, neue auf...
# 214  Als übernommener Mitarbeiter sah ich viele mei...
# 215           Handling relax brauchbar neu fortschritt
#
# [216 rows x 5 columns]

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 3].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df6 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df6
# Out:
#                                                  title
# 0                                                Super  \
# 1    Verbesserungsvorschläge für eine noch bessere ...
# 2                        Gutes Gehalt, flexible Zeiten
# 3                          Nettes Team, gute Erfahrung
# 4                           Führen durch Intransparenz
# ..                                                 ...
# 103                                   Great internship
# 104                                    Top Unternehmen
# 105                                        cobntroller
# 106                                    Product Manager
# 107                                         Gute Sache
#
#                                    author_info rating
# 0    5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1             20. Mai 2023 - Anlagenmechaniker    4,0
# 2           23. Mai 2023 - Industriemechaniker    4,0
# 3                   16. Mai 2023 - Werkstudent    3,0
# 4                      5. Mai 2023 - Ingenieur    2,0
# ..                                         ...    ...
# 103                     23. Jan. 2022 - Intern    5,0
# 104                   22. Juli 2021 - Operator    5,0
# 105                  26. Mai 2021 - Controller    5,0
# 106           10. Sept. 2017 - Product Manager    3,0
# 107                 28. Feb. 2020 - Accountant    3,0
#
#                                                   pros
# 0    Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1    Globale Präsenz: BASF ist ein multinationaler ...
# 2    Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3    Team, Einblicke, Support... Es hat Spaß gemach...
# 4    Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                 ...
# 103                 Learned a lot, staff are very nice
# 104  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 105      work life balance, arbeitszeit, lernfähigkeit
# 106  Großunternehmen, im Allgemeinen sicherer Arbei...
# 107          Kommunikation aktiv statisch proaktiv neu
#
#                                                   cons
# 0            Ein riesiger laden etwas zu groß für mich
# 1    Größe und Komplexität: Als globaler Konzern mi...
# 2    Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3    Die Organisation hat zeitweilig zu wünschen üb...
# 4    Management, Führungskräfte und das gesamte Sys...
# ..                                                 ...
# 103               Non to speak of, very friendly staff
# 104          -Zu wenig Personal -Zu kurze Einarbeitung
# 105  gehalt, wechselgedanken, entwicklung, neue auf...
# 106  Als übernommener Mitarbeiter sah ich viele mei...
# 107           Handling relax brauchbar neu fortschritt
#
# [108 rows x 5 columns]

# %%
dfcomplete=pd.concat([df4, df5, df6], axis=0, ignore_index=True)
dfcomplete.drop_duplicates()
dfcomplete
# Out:
#                                                  title
# 0                                                Super  \
# 1    Verbesserungsvorschläge für eine noch bessere ...
# 2                        Gutes Gehalt, flexible Zeiten
# 3                          Nettes Team, gute Erfahrung
# 4                           Führen durch Intransparenz
# ..                                                 ...
# 319                                   Great internship
# 320                                    Top Unternehmen
# 321                                        cobntroller
# 322                                    Product Manager
# 323                                         Gute Sache
#
#                                    author_info rating
# 0    5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1             20. Mai 2023 - Anlagenmechaniker    4,0
# 2           23. Mai 2023 - Industriemechaniker    4,0
# 3                   16. Mai 2023 - Werkstudent    3,0
# 4                      5. Mai 2023 - Ingenieur    2,0
# ..                                         ...    ...
# 319                     23. Jan. 2022 - Intern    5,0
# 320                   22. Juli 2021 - Operator    5,0
# 321                  26. Mai 2021 - Controller    5,0
# 322           10. Sept. 2017 - Product Manager    3,0
# 323                 28. Feb. 2020 - Accountant    3,0
#
#                                                   pros
# 0    Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1    Globale Präsenz: BASF ist ein multinationaler ...
# 2    Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3    Team, Einblicke, Support... Es hat Spaß gemach...
# 4    Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                 ...
# 319                 Learned a lot, staff are very nice
# 320  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 321      work life balance, arbeitszeit, lernfähigkeit
# 322  Großunternehmen, im Allgemeinen sicherer Arbei...
# 323          Kommunikation aktiv statisch proaktiv neu
#
#                                                   cons
# 0            Ein riesiger laden etwas zu groß für mich
# 1    Größe und Komplexität: Als globaler Konzern mi...
# 2    Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3    Die Organisation hat zeitweilig zu wünschen üb...
# 4    Management, Führungskräfte und das gesamte Sys...
# ..                                                 ...
# 319               Non to speak of, very friendly staff
# 320          -Zu wenig Personal -Zu kurze Einarbeitung
# 321  gehalt, wechselgedanken, entwicklung, neue auf...
# 322  Als übernommener Mitarbeiter sah ich viele mei...
# 323           Handling relax brauchbar neu fortschritt
#
# [324 rows x 5 columns]

# %%
## trying to scrape data from indeed 
## dosent worrk yet

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 4].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df7 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df7
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# ..                                                ...
# 75                                               BASF
# 76                             Bewertung für internem
# 77                                          Bewertung
# 78                                 Chemikant bei BASF
# 79                                                Top
#
#                                   author_info rating
# 0   5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1            20. Mai 2023 - Anlagenmechaniker    4,0
# 2          23. Mai 2023 - Industriemechaniker    4,0
# 3                  16. Mai 2023 - Werkstudent    3,0
# 4                     5. Mai 2023 - Ingenieur    2,0
# ..                                        ...    ...
# 75      21. Juni 2020 - Technischer Einkäufer    4,0
# 76             6. Aug. 2020 - Project Manager    4,0
# 77                            26. Juli 2015 -    4,0
# 78                  23. Juli 2018 - Chemikant    3,0
# 79              14. Mai 2020 - Data Scientist    5,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                ...
# 75  Gutes Gehalt, sicherer Arbeitsplatz, gute Aufs...
# 76               gute Erfahrung für mich und kollegen
# 77  Vielfältige interne Möglichkeiten vorhanden, W...
# 78                 Gutes Lohn und leichte Tätigkeiten
# 79  Vergütung + Zusatzleistungen, Möglichkeiten in...
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# ..                                                ...
# 75  derzeit Stellenabbau, Chemie Image nicht immer...
# 76          langsame und schwierige Prozesse manchmal
# 77      Ähnliches Gehaltsniveau über alle Mitarbeiter
# 78  Arbeitszeiten in Schichten (Tagschicht und Nac...
# 79              Großer Laden, machmal lahm & komplex.
#
# [80 rows x 5 columns]

# %%
dfcomplete=pd.concat([df4, df5, df6, df7], axis=0, ignore_index=True)
dfcomplete.drop_duplicates()
dfcomplete
# Out:
#                                                  title
# 0                                                Super  \
# 1    Verbesserungsvorschläge für eine noch bessere ...
# 2                        Gutes Gehalt, flexible Zeiten
# 3                          Nettes Team, gute Erfahrung
# 4                           Führen durch Intransparenz
# ..                                                 ...
# 399                                               BASF
# 400                             Bewertung für internem
# 401                                          Bewertung
# 402                                 Chemikant bei BASF
# 403                                                Top
#
#                                    author_info rating
# 0    5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1             20. Mai 2023 - Anlagenmechaniker    4,0
# 2           23. Mai 2023 - Industriemechaniker    4,0
# 3                   16. Mai 2023 - Werkstudent    3,0
# 4                      5. Mai 2023 - Ingenieur    2,0
# ..                                         ...    ...
# 399      21. Juni 2020 - Technischer Einkäufer    4,0
# 400             6. Aug. 2020 - Project Manager    4,0
# 401                            26. Juli 2015 -    4,0
# 402                  23. Juli 2018 - Chemikant    3,0
# 403              14. Mai 2020 - Data Scientist    5,0
#
#                                                   pros
# 0    Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1    Globale Präsenz: BASF ist ein multinationaler ...
# 2    Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3    Team, Einblicke, Support... Es hat Spaß gemach...
# 4    Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                 ...
# 399  Gutes Gehalt, sicherer Arbeitsplatz, gute Aufs...
# 400               gute Erfahrung für mich und kollegen
# 401  Vielfältige interne Möglichkeiten vorhanden, W...
# 402                 Gutes Lohn und leichte Tätigkeiten
# 403  Vergütung + Zusatzleistungen, Möglichkeiten in...
#
#                                                   cons
# 0            Ein riesiger laden etwas zu groß für mich
# 1    Größe und Komplexität: Als globaler Konzern mi...
# 2    Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3    Die Organisation hat zeitweilig zu wünschen üb...
# 4    Management, Führungskräfte und das gesamte Sys...
# ..                                                 ...
# 399  derzeit Stellenabbau, Chemie Image nicht immer...
# 400          langsame und schwierige Prozesse manchmal
# 401      Ähnliches Gehaltsniveau über alle Mitarbeiter
# 402  Arbeitszeiten in Schichten (Tagschicht und Nac...
# 403              Großer Laden, machmal lahm & komplex.
#
# [404 rows x 5 columns]

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 5].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df8 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df8
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# ..                                                ...
# 63                                   Great internship
# 64                                    Top Unternehmen
# 65                                        cobntroller
# 66                                    Product Manager
# 67                                         Gute Sache
#
#                                   author_info rating
# 0   5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1            20. Mai 2023 - Anlagenmechaniker    4,0
# 2          23. Mai 2023 - Industriemechaniker    4,0
# 3                  16. Mai 2023 - Werkstudent    3,0
# 4                     5. Mai 2023 - Ingenieur    2,0
# ..                                        ...    ...
# 63                     23. Jan. 2022 - Intern    5,0
# 64                   22. Juli 2021 - Operator    5,0
# 65                  26. Mai 2021 - Controller    5,0
# 66           10. Sept. 2017 - Product Manager    3,0
# 67                 28. Feb. 2020 - Accountant    3,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                ...
# 63                 Learned a lot, staff are very nice
# 64  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 65      work life balance, arbeitszeit, lernfähigkeit
# 66  Großunternehmen, im Allgemeinen sicherer Arbei...
# 67          Kommunikation aktiv statisch proaktiv neu
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# ..                                                ...
# 63               Non to speak of, very friendly staff
# 64          -Zu wenig Personal -Zu kurze Einarbeitung
# 65  gehalt, wechselgedanken, entwicklung, neue auf...
# 66  Als übernommener Mitarbeiter sah ich viele mei...
# 67           Handling relax brauchbar neu fortschritt
#
# [68 rows x 5 columns]

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 7].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df9 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df9
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# 5            Umtrukturierung hat Teams kaputt gemacht
# 6                                   Guter Arbeitgeber
# 7                                 generell ist es gut
# 8                                                 Gut
# 9                                               Super
# 10                                          alles gut
# 11                                     General rating
# 12                                              Great
# 13                                        Regular job
# 14                                                Top
# 15                             Sehr guter Arbeitgeber
# 16                                 BASF Zufriedenheit
# 17  Guter Arbeitgeber - leider werden zu viele Kos...
# 18                             Sehr guter Arbeitgeber
# 19                       Wichtige und tolle Bewertung
# 20                                         Nein Danke
# 21   Innovatives Arbeitsumfeld und angenehme Stimmung
# 22                                               BASF
# 23                                           Sehr gut
# 24                 Eigenverantwortung und Abwechslung
# 25                                     Guter Einstieg
# 26                  Tolle Einblicke in die Chemiewelt
# 27                                   BASF SE - Berlin
# 28                    Keine Strategie-keine Phantasie
# 29                          BASF Services Europe GmbH
# 30                                    Langsamer RIese
# 31                                       Gut-sehr gut
# 32                      Gut, wenn man mal drinnen ist
# 33  Konservatives Unternehmen mit geringem Willen ...
# 34  Work life balance interessiert in vielen Teile...
# 35                                  Guter Arbeitgeber
# 36                                               Basf
# 37                                Sehr gute Bezahlung
# 38        gute Praktikumserfahrung in dem SCM Bereich
# 39                                          Entspannt
# 40                               Junior Asset Manager
# 41                             Größtenteils zufrieden
# 42                                    Product Manager
# 43                                     praktikum basf
# 44                                  Guter Arbeitgeber
# 45                                               BASF
# 46                             Bewertung für internem
# 47                                          Bewertung
# 48                                 Chemikant bei BASF
# 49                                                Top
#
#                                           author_info rating
# 0           5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1                    20. Mai 2023 - Anlagenmechaniker    4,0
# 2                  23. Mai 2023 - Industriemechaniker    4,0
# 3                          16. Mai 2023 - Werkstudent    3,0
# 4                             5. Mai 2023 - Ingenieur    2,0
# 5           26. Apr. 2023 - Finance Senior Specialist    2,0
# 6              29. Apr. 2023 - Senior DevOps Engineer    3,0
# 7                         12. Apr. 2023 - Werkstudent    5,0
# 8                        5. Apr. 2023 - HR Generalist    5,0
# 9                    31. März 2023 - Qualitätsmanager    5,0
# 10    21. Jan. 2022 - Mitarbeiter Technischer Einkauf    5,0
# 11                  20. Jan. 2022 - Junior Controller    4,0
# 12               25. Jan. 2022 - Anonymer Mitarbeiter    4,0
# 13                          8. Feb. 2022 - Accountant    1,0
# 14           19. Jan. 2022 - Technischer Angestellter    5,0
# 15                          28. Dez. 2021 - Chemikant    4,0
# 16               23. Dez. 2021 - Chemical Engineering    4,0
# 17                          3. Dez. 2021 - HR Officer    3,0
# 18        26. Dez. 2021 - Chemikant und Anlagenfahrer    5,0
# 19     24. Dez. 2021 - Assistent der Geschäftsleitung    4,0
# 20               15. Juli 2021 - Anonymer Mitarbeiter    1,0
# 21                23. Apr. 2021 - Key Account Manager    4,0
# 22                    22. März 2021 - Digital Manager    3,0
# 23                  28. Apr. 2021 - Junior Controller    3,0
# 24  14. Dez. 2020 - Werkstudentin Interne und Onli...    5,0
# 25                  10. Apr. 2021 - Patentrechercheur    5,0
# 26                        13. Apr. 2021 - Volontär/in    5,0
# 27                8. Apr. 2021 - Anonymer Mitarbeiter    3,0
# 28                     28. Feb. 2021 - Vice President    3,0
# 29                      9. Apr. 2021 - Senior Officer    4,0
# 30                  22. Apr. 2016 - Produktmanagement    3,0
# 31                           19. Apr. 2016 - Chemiker    4,0
# 32   25. Jan. 2019 - Mitarbeiter Finanzen/Controlling    4,0
# 33        14. März 2017 - Global Supply Chain Manager    3,0
# 34           6. Juli 2018 - Senior Consultant SAP/SCM    2,0
# 35                  3. Okt. 2019 - Marketing Services    4,0
# 36                 5. Mai 2019 - Laboratory Assistant    5,0
# 37                           2. Juli 2020 - Chemikant    4,0
# 38    9. Jan. 2019 - Prakitkant Supply Chain projects    4,0
# 39                    29. Juni 2015 - Project Manager    4,0
# 40               24. März 2019 - Junior Asset Manager    4,0
# 41                      2. Okt. 2019 - Chemielaborant    3,0
# 42                          6. Feb. 2020 - Manager/In    4,0
# 43                      6. Apr. 2020 - Data Scientist    5,0
# 44                     15. Mai 2020 - Product Manager    4,0
# 45              21. Juni 2020 - Technischer Einkäufer    4,0
# 46                     6. Aug. 2020 - Project Manager    4,0
# 47                                    26. Juli 2015 -    4,0
# 48                          23. Juli 2018 - Chemikant    3,0
# 49                      14. Mai 2020 - Data Scientist    5,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# 5   sicherer Arbeitsplatz mit viel Entfaltungsmögl...
# 6   Sicherer Arbeitsplatz, gute Arbeitsauslastung,...
# 7   Attraktive Aufgaben, flexible Arbeitszeit und ...
# 8          Gehalt sowie die Kollegen und Vorgesetzten
# 9              Tolle Firma hab immer gerne gearbeitet
# 10          Gutes Gehalt, gute Vorsorge und Gleitzeit
# 11    Good working environment Good work life balance
# 12              Work-life balance and company culture
# 13  I think that working from home and also workin...
# 14  Tolles Team Unterstützendes Management Hervorr...
# 15  -Respekt wird bei BASF groß geschrieben -Urlau...
# 16  Die Firma bietet ein Komplettpaket. Sehr Innov...
# 17  - flexible Arbeitszeiten - sympathische Kolleg...
# 18     Sicherheit und d unbefristeten Arbeitsvertrag.
# 19                        Die geben einem echtes Geld
# 20                    Zentrale Lage im Berliner Osten
# 21  - Gutes Gehalt - Entspanntes Arbeitsumfeld - E...
# 22  Stabil, renommiert, high Standards. Corporate ...
# 23       Gutes Klima, Sehr nette Kollegen, Homeoffice
# 24  Als Werkstudentin wurden mir bereits nach kurz...
# 25  Am Anfang wird man gut gefördert, geforderte L...
# 26             Tolle Einblicke in die Welt der Chemie
# 27  Als große internationale Firma gibt es viele M...
# 28         Vorteile der BASF SE als Mutterunternehmen
# 29  Nette Kollegen, mobiles Arbeiten, Onboarding-P...
# 30               Gutes Gehalt Faire Work Life Balance
# 31  Sehr gute Bezahlung und freundlicher Umgang, P...
# 32  - Sehr gute Bezahlung - Sehr gute Sozialleistu...
# 33    Grosser Arbeitgeber mit vielfältigen Positionen
# 34  Gehalt gut, einfache Jobs sind oft noch recht ...
# 35  Gut strukturierter Konzern, interessante Aufga...
# 36  Das große Unternehmen hat gute Strukturen star...
# 37  Bezahlung, soziale Leistungen, Arbeitszeiten, ...
# 38  - internationale Projekte - nette Betreuer und...
# 39  Gute Work-Life-Balance, gute Bezahlung, angene...
# 40  Beständig, gute Sozialleistungen, viele Jobopt...
# 41                 Sicherer Job, relativ gutes Gehalt
# 42  Gutes Gehalt und freundliche Kollegen/Vorgesetzte
# 43                         Es war alles gut finde ich
# 44           Gute Firma, nette Kollegen, gutes Gehalt
# 45  Gutes Gehalt, sicherer Arbeitsplatz, gute Aufs...
# 46               gute Erfahrung für mich und kollegen
# 47  Vielfältige interne Möglichkeiten vorhanden, W...
# 48                 Gutes Lohn und leichte Tätigkeiten
# 49  Vergütung + Zusatzleistungen, Möglichkeiten in...
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# 5            Gehalt im Vergleich zum Workload unfair.
# 6   Schlechte Karrieremöglichkeiten als Experte, v...
# 7                     Langes Warten auf neue Aufgaben
# 8                    Umzug nach Berlin war vorgesehen
# 9                    Morgens so früh aufstehen müssen
# 10  Personal wird zunehmend abgebaut, dadurch Arbe...
# 11                Low Salary, promotion is not quick.
# 12               Remuneration is below market average
# 13  I think salaries should be higher to avoid hig...
# 14     Im Vergleich zu vorherigen Arbeitgebern nichts
# 15  -es wird weniger auf die einzelnen Mitarbeiter...
# 16  Die Internetverbindung ist oft nicht ausreichend.
# 17  - Kosteneinsparung merkt man - viele Aufgaben ...
# 18          kenne keine kontra‘s die dagegen sprechen
# 19                     Man muss leider dafür arbeiten
# 20  Chaotische Struktur, fehlende Wertschätzung, s...
# 21  - Typisch Deutsches Unternehmen - Leicht bürok...
# 22  nicht innovativ, sehr hierarchisch, man ist ge...
# 23                           Das Gehalt ist ein Witz.
# 24  In so einem großen Unternehmen muss man sich e...
# 25  Manchmal sollte die Personalabteilung etwas pr...
# 26             sehr chemische Einblicke aber spannend
# 27              Starre Strukturen und geringes Gehalt
# 28  Seit Jahren dümpelt das Geschäft, keine Strate...
# 29                   Die Fluktuation ist relativ hoch
# 30  Übergroße KOnzernstrukturen führen zur Lähmung...
# 31  Zuviele Bewerber, schwer reinzukommen ist manc...
# 32  - Haifischbecken - Für kaufmännische Personen ...
# 33  sehr konservatives Unternehmen; komplexe Organ...
# 34  Höhere Jobgrades werden sehr stark über lastet...
# 35  Kaum Gehaltssteigerungen möglich, trotz berufs...
# 36  Man ist in einem System. Wer damit nicht gut l...
# 37  Langsame Aufstiegschancen, Prozesse sehr langs...
# 38  - traditionale, große Firma mit langsamen Proz...
# 39  Entwicklung geht sehr langsam, vor allem wenn ...
# 40  Hohe Arbeitslast, zahlt weniger als Branchenüb...
# 41  Wenig Wertschätzung, sehr bürokratisch, wenig ...
# 42  Klassisch Konzern eben. Schwierig, Dinge zu be...
# 43                  mehr innovation wäre etwas besser
# 44      Langsam, konservativ, fehlt an klare Richtung
# 45  derzeit Stellenabbau, Chemie Image nicht immer...
# 46          langsame und schwierige Prozesse manchmal
# 47      Ähnliches Gehaltsniveau über alle Mitarbeiter
# 48  Arbeitszeiten in Schichten (Tagschicht und Nac...
# 49              Großer Laden, machmal lahm & komplex.

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 8].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df10 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df10
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# 5            Umtrukturierung hat Teams kaputt gemacht
# 6                                   Guter Arbeitgeber
# 7                                 generell ist es gut
# 8                                                 Gut
# 9                                               Super
# 10                                        Alles Suppi
# 11                                    Top Arbeitgeber
# 12                                  Super Arbeitgeber
# 13                       Wenig Empowerment / sonst OK
# 14                                okay aber nicht gut
# 15  Perfekter Fit zwischen Kunden- und Mitarbeiter...
# 16                                                Gut
# 17                                                Adi
# 18             Gut wenn man schnell einen Job braucht
# 19                                                 Ok
# 20                                  Guter Arbeitgeber
# 21                                    Fallender Riese
# 22                                         Tolle Zeit
# 23                                 Tolles Unternehmen
# 24                                                  .
# 25                             Sehr guter Arbeitgeber
# 26                                           Sehr Gut
# 27                         Da geht was in der Zukunft
# 28                             Gute work-life Balance
# 29                                  Guter Arbeitgeber
# 30                                           Sehr gut
# 31                                    Super Zufrieden
# 32                                      Senior Expert
# 33                                  Gutes Unternehmen
# 34        Hohe Komplexität im herausfordernden Umfeld
# 35      Beste Möglichkeiten um Erfahrungen zu sammeln
# 36                                           Vielfalt
# 37                                       FERIENHELFER
# 38                         Projektmanager bei BASF SE
# 39                  Noch immer der größte Arbeitgeber
#
#                                         author_info rating
# 0         5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1                  20. Mai 2023 - Anlagenmechaniker    4,0
# 2                23. Mai 2023 - Industriemechaniker    4,0
# 3                        16. Mai 2023 - Werkstudent    3,0
# 4                           5. Mai 2023 - Ingenieur    2,0
# 5         26. Apr. 2023 - Finance Senior Specialist    2,0
# 6            29. Apr. 2023 - Senior DevOps Engineer    3,0
# 7                       12. Apr. 2023 - Werkstudent    5,0
# 8                      5. Apr. 2023 - HR Generalist    5,0
# 9                  31. März 2023 - Qualitätsmanager    5,0
# 10             21. Dez. 2021 - Wirtschaftsingenieur    5,0
# 11                        13. Dez. 2021 - Chemikant    5,0
# 12                         6. Dez. 2021 - Ingenieur    4,0
# 13                          2. Dez. 2021 - Director    3,0
# 14            5. Dez. 2021 - Recruitment Specialist    3,0
# 15                  22. Nov. 2021 - Product Manager    5,0
# 16                  24. Nov. 2021 - Franchise Owner    4,0
# 17  19. Nov. 2021 - Custimer Service Representative    3,0
# 18             10. Juni 2021 - Anonymer Mitarbeiter    1,0
# 19                10. Nov. 2021 - Sachbearbeiter/in    4,0
# 20      22. Jan. 2021 - Project Engineering Manager    4,0
# 21            24. Feb. 2021 - Manager Kommunikation    3,0
# 22                     22. Feb. 2021 - Masterarbeit    5,0
# 23                         25. Feb. 2021 - Chemiker    5,0
# 24                        11. Mai 2021 - Accountant    1,0
# 25    20. Jan. 2021 - Laboratory Lead Ecotoxicology    5,0
# 26                      13. Feb. 2021 - Buchhaltung    5,0
# 27                        29. Jan. 2021 - Ingenieur    4,0
# 28                    10. Jan. 2021 - HR Specialist    3,0
# 29                         3. Feb. 2021 - Chemikant    5,0
# 30        19. März 2020 - General Ledger Accountant    4,0
# 31                  15. Sept. 2015 - Phyisklaborant    5,0
# 32      8. Mai 2019 - Digital Transformation Office    3,0
# 33                        4. Dez. 2019 - Buchhalter    5,0
# 34              16. Mai 2017 - Anonymer Mitarbeiter    4,0
# 35                      30. Jan. 2017 - Werkstudent    4,0
# 36    6. Aug. 2017 - Accountant Accounts Receivable    3,0
# 37                                   4. Dez. 2017 -    5,0
# 38                 3. Aug. 2018 - Projektmanager/in    5,0
# 39             22. März 2017 - Anonymer Mitarbeiter    4,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# 5   sicherer Arbeitsplatz mit viel Entfaltungsmögl...
# 6   Sicherer Arbeitsplatz, gute Arbeitsauslastung,...
# 7   Attraktive Aufgaben, flexible Arbeitszeit und ...
# 8          Gehalt sowie die Kollegen und Vorgesetzten
# 9              Tolle Firma hab immer gerne gearbeitet
# 10                   Top Top Top Kollegen Umfeld usw.
# 11  Tolle Kollegen gehabt, immer abwechslungsreich...
# 12  Sicherheit, Stabilität, gute work life Balance...
# 13  Solides Unternehmen, große Sicherheit, Altersv...
# 14  Stetig Arbeitsbalance Sehr gute Kollegen Zentr...
# 15  Zukunftsorientiert, loyal zu Mitarbeiter, nach...
# 16                       Viel Geld und lockere Arbeit
# 17         Zukunftsicher Job das Geld Kommt pünktlich
# 18  - Schneller Bewerbungsprozess - Gut, wenn man ...
# 19          Gute stimmung Gute Kantine Nette Kollegen
# 20  Sicheren Job, vielfälltige Möglichkeiten, Zahl...
# 21  Wer einen SE Vertrag hat, hat wenig zu befürchten
# 22  Sehr gute Unterstützung bei der Erstellung der...
# 23             Professionelle Atmosphäre in der Firma
# 24  leichte und schnelle Bewerbung internationelle...
# 25  Hoher Schutz der Angestellten Gutes Gehalt Tea...
# 26        Effective und super arbeit. Sehr oganisiert
# 27    Modern, international, Gehalt, Karriere, Reisen
# 28  Möglichkeit zu Entwicklung und eine gute work-...
# 29  Gutes Gehalt, gute Sozialleistungen wie Betrie...
# 30  Teamgeist, verschiedene Nationalitäten unter e...
# 31  es wird viel für Mitarbeiter gemacht. Super at...
# 32  In Sachen Arbeitsplatzsicherheit und Zusatzlei...
# 33  Super Mitarbeiter und Team Leiter , flexible A...
# 34  Betriebs-Kita, Aktienprogramm für alle Mitarbe...
# 35  Bereichsübergreifendes Denken und Handeln, vie...
# 36  Kollegen aus aller Welt, vielfältige Aufgaben,...
# 37  Mit der Tätigkeit verschafft man sich einen gu...
# 38  Innovative, arbeitnehmerfreundliche, weltweit ...
# 39  Viele verschiedene Menschen viele verschiedene...
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# 5            Gehalt im Vergleich zum Workload unfair.
# 6   Schlechte Karrieremöglichkeiten als Experte, v...
# 7                     Langes Warten auf neue Aufgaben
# 8                    Umzug nach Berlin war vorgesehen
# 9                    Morgens so früh aufstehen müssen
# 10         Bisher keine Kontras bei der BASF gefunden
# 11           Schichtarbeit ist nicht zu unterschätzen
# 12  Lange und zähe Kommunikationswege Atmosphäre t...
# 13  träge, schwierige Enstcheidungsprozesse, fehle...
# 14  Niedrieges Gehalt wenig Anerkennung kleine Her...
# 15  manchmal in Entscheidungen noch nicht schnell ...
# 16     Schicht. Schlafstörungen. Zeit. Kleine Nummer.
# 17  Ungeldudich Entfernung nicht immer nette Kollegen
# 18  - schlechte Bezahlung - Überarbeitung - Keine ...
# 19                       Es ist ein ganz normaler Job
# 20  Wenn du High Potential bist, machst du Karrier...
# 21  Einsparungen zerstören Unternehmenskultur und ...
# 22                        Es gibt nichts zu bemängeln
# 23            In der Firma herrscht starke Anonymität
# 24  nidriges Gehalt schlechtes Management kein Auf...
# 25  Zu komplexe Prozesse die sehr verlangsamen Unn...
# 26           nicht viel dagegen. Alle sind freundlich
# 27        EDV, Abläufe, Prozesse, Regeln, Ausstattung
# 28       Das Gehalt liegt unter dem branchenstandard.
# 29                           eins zwei drei vier fünf
# 30  Gehalt, Wissentransfer, Unfähigkeit von manche...
# 31  Kastensystem. Was auf dem Schein steht zählt b...
# 32  Eigene Kreativität und auch Transparenz der Ma...
# 33  Gehalt könnte höher sein, bei anderen Firmen z...
# 34  Komplexe Organisation, lange Entscheidungswege...
# 35  ein Weiterkommen im Unternehmen ist meist am V...
# 36  übertriebene Hierachien, Teamleiter gegen stat...
# 37     Man sollte sich an die Arbeitszeiten gewöhnen.
# 38                 durch die Größe etwas schwerfällig
# 39  sehr langsame Abwicklung von Vorgängen man ist...

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 9].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df11 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df11
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# 5            Umtrukturierung hat Teams kaputt gemacht
# 6                                   Guter Arbeitgeber
# 7                                 generell ist es gut
# 8                                                 Gut
# 9                                               Super
# 10        Toller Arbeitgeber mit spannenden Projekten
# 11                      Strengen / Steilen Hierarchie
# 12                                 Fairer Arbeitgeber
# 13                                 Bester Arbeitgeber
# 14  Guter Arbeitgeber in der Metropolregion Rhein-...
# 15                                                puh
# 16            Nette und fähige Mitarbeite, guter Lohn
# 17                            Gutes kollegiales Klima
# 18                                  Ausnutzungsprofiz
# 19                                   gute Bedingungen
# 20                                               Toll
# 21                                          Alles gut
# 22                                             Klasse
# 23                                               BASF
# 24                                  Guter Arbeitgeber
# 25                                    Gute Anstellung
# 26                                  Aniliner forever!
# 27                                                Gut
# 28                                                Gut
# 29                                     Prima Nebenjob
# 30                                         Super Team
# 31                               Sehr gute Atmosphäre
# 32                                   Business Analyst
# 33                                           Top-Down
# 34                                  Guter Arbeitgeber
# 35                                  Guter Arbeitgeber
# 36                                  Global Lead Buyer
# 37                                          Recruiter
# 38                                    Top Arbeitgeber
# 39                                  Guter Arbeitgeber
#
#                                           author_info rating
# 0           5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1                    20. Mai 2023 - Anlagenmechaniker    4,0
# 2                  23. Mai 2023 - Industriemechaniker    4,0
# 3                          16. Mai 2023 - Werkstudent    3,0
# 4                             5. Mai 2023 - Ingenieur    2,0
# 5           26. Apr. 2023 - Finance Senior Specialist    2,0
# 6              29. Apr. 2023 - Senior DevOps Engineer    3,0
# 7                         12. Apr. 2023 - Werkstudent    5,0
# 8                        5. Apr. 2023 - HR Generalist    5,0
# 9                    31. März 2023 - Qualitätsmanager    5,0
# 10                  25. Okt. 2021 - Projektmanager IT    5,0
# 11         16. Juni 2021 - SAP Master Data Specialist    2,0
# 12                          23. Aug. 2021 - Chemikant    4,0
# 13                   6. Okt. 2021 - Projektmanager/in    5,0
# 14                 20. Sept. 2021 - Senior Specialist    4,0
# 15                 10. Dez. 2021 - Chemiefacharbeiter    1,0
# 16                1. Aug. 2021 - Anonymer Mitarbeiter    5,0
# 17                         28. Sept. 2021 - Recruiter    3,0
# 18                12. Nov. 2021 - Master Data Officer    1,0
# 19                         24. Sept. 2021 - Ingenieur    4,0
# 20                         24. Nov. 2020 - HR Manager    4,0
# 21                 9. Nov. 2020 - Procurement Manager    4,0
# 22            12. Nov. 2020 - Bereichsleiter Logistik    5,0
# 23                  22. Nov. 2020 - Anlagenmechaniker    5,0
# 24                      20. Okt. 2020 - Feuerwehrmann    5,0
# 25                          11. Okt. 2020 - ingénieur    4,0
# 26                       26. Sept. 2020 - Laborleiter    5,0
# 27                           6. Jan. 2021 - Techniker    1,0
# 28  5. Okt. 2020 - Contract and Tax Reporting Manager    4,0
# 29                        9. Sept. 2020 - Werkstudent    4,0
# 30                         23. Nov. 2017 - Internship    4,0
# 31                         1. Feb. 2018 - Werkstudent    5,0
# 32                   21. Jan. 2019 - Business Analyst    4,0
# 33            3. Juni 2019 - Administrative Assistant    3,0
# 34                          18. Juli 2020 - Ingenieur    4,0
# 35                                    22. Aug. 2016 -    4,0
# 36               29. Dez. 2016 - Anonymer Mitarbeiter    4,0
# 37                          31. Aug. 2018 - Recruiter    4,0
# 38                    23. Sept. 2018 - Duales Studium    5,0
# 39             20. März 2019 - Senior Project Manager    5,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# 5   sicherer Arbeitsplatz mit viel Entfaltungsmögl...
# 6   Sicherer Arbeitsplatz, gute Arbeitsauslastung,...
# 7   Attraktive Aufgaben, flexible Arbeitszeit und ...
# 8          Gehalt sowie die Kollegen und Vorgesetzten
# 9              Tolle Firma hab immer gerne gearbeitet
# 10             Abwechselnde und spannende IT Projekte
# 11  Wenn Sie eine Fünf-zu-Neun-Mentalität haben, i...
# 12  I'm Vergleich zu anderen Unternehmen ist die B...
# 13  Flexible Arbeitsteilung, überdurchschnittliche...
# 14  - attraktives Gehalt, sehr gute Sozialleistung...
# 15               kollegen sind wirklich toll wirklich
# 16  Das Übliche bei Großunternehmen: Sicherer Job ...
# 17       Arbeitsatmosphäre und Kollegen sind sehr gut
# 18  gut für Leute die mit leichte Arbeit und wenig...
# 19                           gute Arbeit bei der BASF
# 20  Es gab viele Entwicklungsmöglichkeiten und all...
# 21           Ich bin noch recht neu und warte noch ab
# 22                            Alles gut bei der BASF.
# 23  faires Gehalt Firmenwagen ausreichende Schutzv...
# 24                 Gutes Gehalt und guter Arbeitgeber
# 25  Nicht nur Gehalt, sondern auch Extras (Essen, ...
# 26  Sehr sicheres Arbeitsumfeld mit vielen Entfalt...
# 27                      Sehr gute Fima mit gute Image
# 28                   Gutes Geld bei guter Arbeitszeit
# 29  Hohes Gehalt, nette Kollegen, interessante Tät...
# 30  Super Team, tolle Arbeitsumgebung, viel zu ler...
# 31          Entspanntes Arbeiten mit netten Kollegene
# 32  Kollegen, Produkte, Einstiegsgehalt, Home-Offi...
# 33  Gehalt, Vorteile Großkonzern, Tarifvertrag, La...
# 34        - das Betriebsklima ist gut, - gutes Gehalt
# 35  flache Hierachie gute Bezahlung gutes Klima Ab...
# 36    sicher, nette Kollegen, global, Weltmarktführer
# 37     Work Life Balance , Benefits ,mobiles arbeiten
# 38                 International sehr gut vertreten .
# 39            Gutes Gehalt und flexible Arbeitszeiten
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# 5            Gehalt im Vergleich zum Workload unfair.
# 6   Schlechte Karrieremöglichkeiten als Experte, v...
# 7                     Langes Warten auf neue Aufgaben
# 8                    Umzug nach Berlin war vorgesehen
# 9                    Morgens so früh aufstehen müssen
# 10  Fehlende Unternehmensweite Projektmethodik zur...
# 11  Mit ein typisches Konzerunternehmen, kommt vie...
# 12  Es gab Vorgesetzte die Mitarbeiter von oben he...
# 13  Befristete Verträge, kaum Chance unbefristeten...
# 14                         - zu konservativ und träge
# 15                    fima ist eine reinste verarsche
# 16  Das Übliche bei Großunternehmen: Groß, träge, ...
# 17                Gehalt sollte besser sein als jetzt
# 18          Die Firma ist da um die Leute auszunutzen
# 19                    keine die ich hier nennen würde
# 20                        Das Gehalt ist sehr niedrig
# 21  bisher noch keine, ich muss noch alles kennenl...
# 22                    Keine!Es ist alles gut bei BASF
# 23                   an manchen Orten relativ dreckig
# 24     Viele Schichten die im Jahr abgeleistet werden
# 25  Teilweise schwierige Arbeitsatmosphäre, sonst ...
# 26  Teilweise recht konservative Strukturen im Unt...
# 27                     Kann besser werden allen ebene
# 28  Standort ist schrecklich ludwigshafen ist schr...
# 29  Wenig Kommunikation, hoher workload, wenig ver...
# 30  Sehr hierarchisch, Einstellungsstop, keine sch...
# 31       Eigentlich kaum Nachteile bezüglich der BASF
# 32  Intransparenz, konservative Führung, Entwicklu...
# 33  Hierarchie durch und durch.... wenig Mitarbeit...
# 34                   Ich kann keine Kontras benennen.
# 35           Wochenendarbeit kommt min 1x im Jahr vor
# 36  keine Individiualität, bürokratisch, komplizie...
# 37  Keine klimatisierten Räume und Großraumbüros, ...
# 38          Sehr großes Unternehmen, die Masse zählt.
# 39     Verkehr ist schlimm zu den Hauptverkehrszeiten

# %% [markdown]
# ### more mannual page changing

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 50, 10].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
import pandas as pd
df12 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df12
# Out:
#                                                 title
# 0                                               Super  \
# 1   Verbesserungsvorschläge für eine noch bessere ...
# 2                       Gutes Gehalt, flexible Zeiten
# 3                         Nettes Team, gute Erfahrung
# 4                          Führen durch Intransparenz
# 5            Umtrukturierung hat Teams kaputt gemacht
# 6                                   Guter Arbeitgeber
# 7                                 generell ist es gut
# 8                                                 Gut
# 9                                               Super
# 10                                         Gute Firma
# 11                                 Business Reporting
# 12                                Accounts receivable
# 13                               sicherer Arbeitgeber
# 14                                  Guter Arbeitgeber
# 15  Sicherer Arbeitgeber mit Nachteilen im Gehalt ...
# 16                                               Toll
# 17  Solide, manchmal etwas zu konservativ und zu w...
# 18                             Gut für den Lebenslauf
# 19                                  Guter Arbeitgeber
# 20           Langsamer Konzern; Abteilung entscheidet
# 21  Hoch-professionell, aber schwerfällig und poli...
# 22  Großer Tanker auf dem Ozean - langsam, aber un...
# 23                                  Lager Mitarbeiter
# 24                                            BASF SE
# 25                          Kein Job für die Ewigkeit
# 26                           Freiheit am Arbeitsplatz
# 27                     Praktikant Personalentwicklung
# 28              Nette Kollegen bei unfairer Bezahlung
# 29                      Es geht leider weiter bergab.
# 30                                   Schlecht Bezahlt
# 31                                               Gute
# 32  Sicherer Job, da Personalbestand am unteren Li...
# 33                                   Great internship
# 34                                    Top Unternehmen
# 35                                        cobntroller
# 36                                    Product Manager
# 37                                         Gute Sache
#
#                                           author_info rating
# 0           5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1                    20. Mai 2023 - Anlagenmechaniker    4,0
# 2                  23. Mai 2023 - Industriemechaniker    4,0
# 3                          16. Mai 2023 - Werkstudent    3,0
# 4                             5. Mai 2023 - Ingenieur    2,0
# 5           26. Apr. 2023 - Finance Senior Specialist    2,0
# 6              29. Apr. 2023 - Senior DevOps Engineer    3,0
# 7                         12. Apr. 2023 - Werkstudent    5,0
# 8                        5. Apr. 2023 - HR Generalist    5,0
# 9                    31. März 2023 - Qualitätsmanager    5,0
# 10        19. Aug. 2021 - Chemikant und Anlagenfahrer    4,0
# 11                  29. Aug. 2021 - Senior Controller    3,0
# 12  13. Aug. 2021 - Officer Accounts Receivables/C...    1,0
# 13                         1. Sept. 2021 - Manager/In    4,0
# 14                      9. Juli 2021 - Betriebsleiter    4,0
# 15                  11. Apr. 2021 - Produktentwickler    3,0
# 16                  27. Aug. 2021 - Chemical Engineer    5,0
# 17                     31. Mai 2021 - Patent Attorney    4,0
# 18                          14. Juli 2021 - Praktikum    3,0
# 19                3. Juni 2021 - Anonymer Mitarbeiter    5,0
# 20                        15. Apr. 2020 - Werkstudent    3,0
# 21                           13. Okt. 2017 - Director    4,0
# 22               11. Jan. 2018 - Anonymer Mitarbeiter    4,0
# 23  4. Aug. 2018 - Lagermitarbeiter und Staplerfahrer    2,0
# 24                          26. Jan. 2016 - Chemikant    5,0
# 25                         14. Juni 2017 - Accountant    4,0
# 26                       3. Juni 2019 - Werkstudentin    3,0
# 27               17. Okt. 2016 - Anonymer Mitarbeiter    4,0
# 28                  25. Jan. 2016 - Fachliche Führung    2,0
# 29               11. Apr. 2019 - Anonymer Mitarbeiter    2,0
# 30               22. Feb. 2020 - Anonymer Mitarbeiter    1,0
# 31               18. Juni 2022 - Anonymer Mitarbeiter    4,0
# 32   7. Jan. 2022 - Chemielaborant Qualitätskontrolle    3,0
# 33                             23. Jan. 2022 - Intern    5,0
# 34                           22. Juli 2021 - Operator    5,0
# 35                          26. Mai 2021 - Controller    5,0
# 36                   10. Sept. 2017 - Product Manager    3,0
# 37                         28. Feb. 2020 - Accountant    3,0
#
#                                                  pros
# 0   Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1   Globale Präsenz: BASF ist ein multinationaler ...
# 2   Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3   Team, Einblicke, Support... Es hat Spaß gemach...
# 4   Kündigungsschutz (betrieblich bedingt) von 5 J...
# 5   sicherer Arbeitsplatz mit viel Entfaltungsmögl...
# 6   Sicherer Arbeitsplatz, gute Arbeitsauslastung,...
# 7   Attraktive Aufgaben, flexible Arbeitszeit und ...
# 8          Gehalt sowie die Kollegen und Vorgesetzten
# 9              Tolle Firma hab immer gerne gearbeitet
# 10  Gutes Gehalt und sozial Leistung. Es ist sehr ...
# 11         Jobsicherheit ist ein sehr großer Vorteil.
# 12  They accept people not speaking German with En...
# 13  Sicherer Job Vielfalt Gute Bezahlung Wechsel m...
# 14  Sicherer Arbeitsplatz, interesante Aufgaben. G...
# 15  + Sicherer Arbeitgeber + Arbeitnehmerfreundlic...
# 16                  Es wurde immer Leistung gefordert
# 17  solide, gründlich, sicher, vielseitig aufgestellt
# 18  Hohe Lernkurve, nette Mitarbeiter, gut im Lebe...
# 19  Diversität, empowerment und eine tolle Unterne...
# 20  Work-Life Balance, Gehalt, Kantine, Arbeitsbed...
# 21  - Fürsorge für den Mitarbeiter - Höchste Profe...
# 22  - Top-Unternehmen in der Chemiebranche - Viele...
# 23  Gutes Sozialpaket für Arbeitnehmer: Tarifgehal...
# 24  Es ist ein sicherer Arbeitgeber. Die arbeits A...
# 25  Relativ junge Belegschaft, Zentrale Lage, Gut ...
# 26  BASF bietet viele Freiheiten. Angefangen von d...
# 27  Viel Verantwortung und bedeutende Aufgaben. We...
# 28  - kollegialer Zusammenhalt ist vorhanden - gen...
# 29  Recht sicherer Arbeitsplatz (aber auch dies än...
# 30                          es gibt Chancen zu lernen
# 31  Tolle Lernkurve mit nett leute und attractive ...
# 32  Hohe Sicherheitskultur mit regelmäßigen Schulu...
# 33                 Learned a lot, staff are very nice
# 34  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 35      work life balance, arbeitszeit, lernfähigkeit
# 36  Großunternehmen, im Allgemeinen sicherer Arbei...
# 37          Kommunikation aktiv statisch proaktiv neu
#
#                                                  cons
# 0           Ein riesiger laden etwas zu groß für mich
# 1   Größe und Komplexität: Als globaler Konzern mi...
# 2   Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3   Die Organisation hat zeitweilig zu wünschen üb...
# 4   Management, Führungskräfte und das gesamte Sys...
# 5            Gehalt im Vergleich zum Workload unfair.
# 6   Schlechte Karrieremöglichkeiten als Experte, v...
# 7                     Langes Warten auf neue Aufgaben
# 8                    Umzug nach Berlin war vorgesehen
# 9                    Morgens so früh aufstehen müssen
# 10  Man muss alles selbständig lernen und manche I...
# 11  Mitarbeiterfluktuation ist leider sehr hoch. G...
# 12  They avoid give a permanent contract principal...
# 13  Groß Träge Sehr regelbasiert Überreguliert Nic...
# 14  Bürokratie. Zu starke Arbeitsteilung und Proze...
# 15  + Starre Strukturen und wenig Innovation + Kei...
# 16             Es gab wenig Aufstiegschancen für mich
# 17         zu viele Bedenken / zu wenig risiko-bereit
# 18  Wenn man keine Eltern hat, die einen finanzier...
# 19  Keine aus meiner Sicht. Sollte es Themen geben...
# 20  Die BASF ist ein riesiger Konzern und das merk...
# 21  - Bürokratisch, schwerfällig und politisch - Ü...
# 22  - Einige alte "Aniliner" lassen jegliche Dynam...
# 23  Geld ist leider nicht alles.... Schichtarbeit ...
# 24  Da es ein Chemieunternehmen ist besteht immer ...
# 25  Shared Service Center mit schlechtem Haustarif...
# 26  Leider ist zu bemängeln das es sehr viele befr...
# 27  Praktikanten werden vom Unternehmen nicht als ...
# 28  - unfaire und niedrige Gehaltsstruktur - viele...
# 29  Unternehmensstrategie wird permanent angepasst...
# 30                   Wenig bezahlt und zu viel stress
# 31                Nicht so viel freiheit/ möglichkeit
# 32  Demografischer Wandel am Standort zu spät entg...
# 33               Non to speak of, very friendly staff
# 34          -Zu wenig Personal -Zu kurze Einarbeitung
# 35  gehalt, wechselgedanken, entwicklung, neue auf...
# 36  Als übernommener Mitarbeiter sah ich viele mei...
# 37           Handling relax brauchbar neu fortschritt

# %% [markdown]
# ### contracting all dataframes, dropping duplicates

# %%
dfcomplete=pd.concat([df4, df5, df6, df7, df8, df9, df10, df11, df12], axis=0, ignore_index=True)
dfcomplete.drop_duplicates()
dfcomplete
# Out:
#                                                  title
# 0                                                Super  \
# 1    Verbesserungsvorschläge für eine noch bessere ...
# 2                        Gutes Gehalt, flexible Zeiten
# 3                          Nettes Team, gute Erfahrung
# 4                           Führen durch Intransparenz
# ..                                                 ...
# 635                                   Great internship
# 636                                    Top Unternehmen
# 637                                        cobntroller
# 638                                    Product Manager
# 639                                         Gute Sache
#
#                                    author_info rating
# 0    5. Mai 2023 - Chemikant und Anlagenfahrer    5,0  \
# 1             20. Mai 2023 - Anlagenmechaniker    4,0
# 2           23. Mai 2023 - Industriemechaniker    4,0
# 3                   16. Mai 2023 - Werkstudent    3,0
# 4                      5. Mai 2023 - Ingenieur    2,0
# ..                                         ...    ...
# 635                     23. Jan. 2022 - Intern    5,0
# 636                   22. Juli 2021 - Operator    5,0
# 637                  26. Mai 2021 - Controller    5,0
# 638           10. Sept. 2017 - Product Manager    3,0
# 639                 28. Feb. 2020 - Accountant    3,0
#
#                                                   pros
# 0    Gutes Gehalt, gute Arbeitszeit, gute Kollegen,...  \
# 1    Globale Präsenz: BASF ist ein multinationaler ...
# 2    Das Einstiegsgehalt ist für einen Ausbildungsb...
# 3    Team, Einblicke, Support... Es hat Spaß gemach...
# 4    Kündigungsschutz (betrieblich bedingt) von 5 J...
# ..                                                 ...
# 635                 Learned a lot, staff are very nice
# 636  -Gehalt ist fair -Angenehme Vorgesetzte -Genug...
# 637      work life balance, arbeitszeit, lernfähigkeit
# 638  Großunternehmen, im Allgemeinen sicherer Arbei...
# 639          Kommunikation aktiv statisch proaktiv neu
#
#                                                   cons
# 0            Ein riesiger laden etwas zu groß für mich
# 1    Größe und Komplexität: Als globaler Konzern mi...
# 2    Aufstiegsmöglichkeiten aufgrund der hohen Meng...
# 3    Die Organisation hat zeitweilig zu wünschen üb...
# 4    Management, Führungskräfte und das gesamte Sys...
# ..                                                 ...
# 635               Non to speak of, very friendly staff
# 636          -Zu wenig Personal -Zu kurze Einarbeitung
# 637  gehalt, wechselgedanken, entwicklung, neue auf...
# 638  Als übernommener Mitarbeiter sah ich viele mei...
# 639           Handling relax brauchbar neu fortschritt
#
# [640 rows x 5 columns]

# %% [markdown]
# ### converting to cvs

# %%
dfcomplete.to_csv('dataset2.csv')

# %% [markdown]
# ## Experimental Section

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json

# %%
df2 = pd.DataFrame({'review_title': [],'review':[],'author':[],'rating':[]})

# %%
for i in range(10,140,20):
     url = (f'https://de.indeed.com/cmp/Basf-df1bf734/reviews?fcountry=DE&sort=helpfulness&start={i}')
     header = {"User-Agent":"Mozilla/5.0 Gecko/20100101 Firefox/33.0 GoogleChrome/10.0"}
     page = requests.get(url,headers = header)
     soup = BeautifulSoup(page.content, 'lxml')
     print(soup)
     results = soup.find("div",{ "id" : 'cmp-container'})
     elems = results.find_all(class_='cmp-Review-container')
     for elem in elems:
         title = elem.find(attrs = {'class':'cmp-Review-title'})
         review = elem.find('div', {'class': 'cmp-Review-text'})
         author = elem.find(attrs = {'class':'cmp-Review-author'})
         rating = elem.find(attrs = {'class':'cmp-ReviewRating-text'})
         df = df.append({'review_title': title.text,
          'review': review.text,
        'author': author.text,
          'rating': rating.text
            }, ignore_index=True)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Just a moment...</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex,nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
# </head>
# <body class="no-js">
# <div class="main-wrapper" role="main">
# <div class="main-content">
# <noscript>
# <div id="challenge-error-title">
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# </div>
# </noscript>
# <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=7c4961f87e993686')"></div>
# <form action="/cmp/Basf-df1bf734/reviews?fcountry=DE&amp;sort=helpfulness&amp;start=10&amp;__cf_chl_f_tk=lX4W97novld3wpU1mrKSpvMsH9ngR7E60bp9xmq_17s-1683629438-0-gaNycGzNCzs" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
# <input name="md" type="hidden" value="mIeUzjVydHH8Tsp1LUyVYs2i8tnjXXnuFmnjNbxGeds-1683629438-0-AatnIV2d7-TAAS7Ijcgt7bTRdazsyZG3PHXzAaFwr-o3fxxtdgrHV22zvQQXg91BKKD3pHQD6HhnSJMRS9BNjxmeOUsMkEWy2nNhHrHm2STf9JwZzeyn12lD7VCgV3zi0qV88AwqNmHdTga0ZAuj1NwRNsZD5mFRjNZrys2-a4dM5H2aBAiHp3ImObP1gjd-eL2ZY71e1arBNAmpjmtj223fMchIEsMAjNxZ83dV9hiiy0Q6Ciwf8Ky6Gx-3ooinuDPKVYbMr_dPqd6N4_bc6eN5jWcZwuU7r0uiwPeA-sj3rBFo_zD64L2PGkMarzY9C7QRHDUcM6zRtLpIUp3rLiKr66V8bQ1nSOKlk4xXWK6L6jKcgvyCIK1YFi9ZeTBkOshFAlZpU-dftz_I67R9TzXNmoZ4FVxJizCLqEir7d5q4bttB_GP5Q1QKylI9vBXePpNV-iNympkwttvYrDiorSkR6jfpnyFXs6tuPYPnIibS64mQ0lOY3ie3sL8wGAEsE-J3DGBt_BZ1vRf679hloX7k7OimHUC116jdZQ7iLvjw802ZCReFhSLiKHtwbr6Pm7y3LDMT3RU8JAoequcn3cLPqsTL5mqC9gPnmcA8Bg8bHmUaZr8SOwAEEkvPO1zxlbu11-Rh7Esq0W15vKHUEx49wOgHur8xNZfFuhVNa48wh-zPrSIYCT9yggxEdRf7rGbekTWh-eUztMxn6qir77se9CWCn99RepMd_69gx9XpPlGVgQCpsQIPRVPUzMHMaLFTxxeFl7VHEHfIhlF5IoUrVjARJ6WFf6jNOXZAapFix8xSH7-IgGYjQf-WSK4Q5R4MXtqyd-lIzr_jDm5xTSuw2-alwta4SZy8jUU5301gGBubbGvvOY3itYdIQUcofkJFiYxMN1OL4j3iBxd40Ryrsw4hMHwGkMI8CdkyNVI_NAJjOaljy2YKHLhJvu1CX0j0-RyslIDdQXCrc3od5EUE0WjcStgbLmogQT4mlDrwsS_kS8XgJCVA2ZBvl3gAFpk4kvdHsSFuHNVDHkBWKwLrXGoYVKGbAcBe4QenSxvdBW-3eMuOgOcweo45UdC6y53qZR-QDaEEQZL5qh_LNU49Ts7HmhpdkESqSg3f7xXSUbBaga4y_ZNm_J8WxCtjDjZadFPXkhOZMljBG2ZNZlsM8qnh44ZhzETTZgBb1AOMZHL1dUHoadeZDMP61NBLVJOk5p54uGoxqU3N8GA-cg_Tkxo3V22X1l4VhN2HQgJbfrbmxrGWeEshFTwr3JYIab_O9SBtgvEybwFPVXUEgNPWr_bUjjZ4BEXu5tjkgvr__CliXGoxrGXWe3jGJ-eXUYeKnPGM_2ck0ZHmc-YW1vjEZVCCiKviIO0XSsnXRZk5WUQz8N8eUvhTqLcjnahhZAyUol3KP3sLAlLzjjgxVlhfdtzGhc3WXiGHWa6lxVJUva3wj3Z_h1XDbY6X71xFVbDVLXHPpphqdYh6N6dkKBInRxgNzD-mueRqUUXFSVid6tlaCAHAzTE2g1peY0w9COdfWh0m1xDbycXef8-M4NyloWCWMrrS6KY_dZN_XlhWO0nV2aPqkh5Y-KQdbPKDO4gmw7Hcms4WWy_k0ZMEJlFHEU073fZm5Q12VcaMj1_-HVnaaJTty5GSxBIckKwFMy0eBBV_Qgl7Hk9dj53brv-4g-fD3c_wYl1KmrgLji7l2ES2k4-b2hJLLID6-rGrQAu-g9OCjnmy9P5ISGDK_chjQwsLYTav8lwU0GlwGjU2r930ukTDhrfr2IONk6OFkNepx8XPjwi6SVq5q6nI_PWbDia5GnoDCUL2Z18YQLUs5JXF045N0UvPMRJ8jeYopePT9qY2_ipz1Q82_1BJtwdaC-Mlh3lb_QdLYjqhhCPkIt88rlskkI0dp15aWrEkNter_gfCN9kKpfLWpjsTLDqod-TIHFzmAmYy1FHIOg6OQxV0dXFgFUFKYkUZrutkR27-_lR8ysYhCoaAykApni8WTgLJ5IMdW5CytbBkh4mwQzpdutWny4hGjzvQTBc29avaNfTRnBIsjbEPvPBoq0hFgCiWbHDUS09w0C0zvA0zCt3cMPQZlCCNInilvQjfcMZuqX-sMfYlGk_Y14KSyBJ3Rz3SLvZykTr79LK87659eLCl5o4PXEcOC3iHX8DC8252LJ9cgrXgkhbCoesazofNL7XgD2db1ZE5pG6z0uCY2mfBOdkSSYEcjIBLV25yIOafgnOzGztDaA4vALzTNA3dMtdqzhKo-AYlSLxY_CcwvvJYSqH2xhieSImnm0DEjqtbO9AMxMJJBcJxYljdxIYxGqm7_H0dV-Ztm6Rep6wMFFDt1geNt1zaiuTb9pCL8aAESMcMF-Is77oLn7yTYY1DD6fjLxbjrgs-4JwRCJmjFIMz8ol8UquVWoE4w6cyjMZ_f_jR50hvSnqkoB832ZcQbd_Es_xoYWqDR4DElJ_gRh9cTXU0fDBBv4FmETIaatGwHnYu4ifYAuhHsefmCv2s0vfyxWNOu0D4wnQ41Mzaiv3J0hYbX8pSPOLLbJ2R1B3pWBJxRWTiHKBvvXFXDFNOnHDirKrcpyeFpOZfulqp5VG2nLjb21SLls9gnmBZClVVIGf_enrTwl7GZ1K3pdh_foISSyt-CsyAqHgWjaE7clHzYrmdHbBwjvnIdt9HhnJfpCOHqssGoIEabHeSEMbtSn9Rz6nF-Wr4ToyifgJF8MMCaS-QMAB861a2HHRzTgX55LuW9rvBnGarjVHP4po53z4GvfuSYXtPy4HTQul_xE7zgCywV7_sAaEw2SwGQ"/>
# </form>
# </div>
# </div>
# <script>
#     (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'de.indeed.com',
#             cType: 'managed',
#             cNounce: '41642',
#             cRay: '7c4961f87e993686',
#             cHash: '196ad1653ab78e9',
#             cUPMDTk: "\/cmp\/Basf-df1bf734\/reviews?fcountry=DE&sort=helpfulness&start=10&__cf_chl_tk=lX4W97novld3wpU1mrKSpvMsH9ngR7E60bp9xmq_17s-1683629438-0-gaNycGzNCzs",
#             cFPWv: 'g',
#             cTTimeMs: '1000',
#             cMTimeMs: '0',
#             cTplV: 5,
#             cTplB: 'cf',
#             cK: "",
#             cRq: {
#                 ru: 'aHR0cHM6Ly9kZS5pbmRlZWQuY29tL2NtcC9CYXNmLWRmMWJmNzM0L3Jldmlld3M/ZmNvdW50cnk9REUmc29ydD1oZWxwZnVsbmVzcyZzdGFydD0xMA==',
#                 ra: 'TW96aWxsYS81LjAgR2Vja28vMjAxMDAxMDEgRmlyZWZveC8zMy4wIEdvb2dsZUNocm9tZS8xMC4w',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY4MzYyOTQzOC44MDUwMDA=',
#                 m: 'ztrJNcgsFzLpZgXaDQljEaj/IUhBD6Q0SYXz3zCSQ9c=',
#                 i1: 'bWmZvJsuacJK20dBSLg1zA==',
#                 i2: 'D86s6R37couXCoi6tbpHCA==',
#                 zh: '2kfjrLYfAVNem19Lin3oP+VKo7ladb55se1eVtiLLnQ=',
#                 uh: 'HPZ61h1sVqymKDmpr8aYacjtWX883LGJRQfd48hmk4A=',
#                 hh: 'duBzhYBbvqxSyiy1fxodihGSwnDR/UBKr0ppYffbXk8=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7c4961f87e993686');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=7c4961f87e993686';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/cmp\/Basf-df1bf734\/reviews?fcountry=DE&sort=helpfulness&start=10&__cf_chl_rt_tk=lX4W97novld3wpU1mrKSpvMsH9ngR7E60bp9xmq_17s-1683629438-0-gaNycGzNCzs" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
# </script>
# </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 8
#       6 print(soup)
#       7 results = soup.find("div",{ "id" : 'cmp-container'})
# ----> 8 elems = results.find_all(class_='cmp-Review-container')
#       9 for elem in elems:
#      10     title = elem.find(attrs = {'class':'cmp-Review-title'})
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

url = 'https://www.indeed.com/cmp/BASF/reviews'

# Send a request to the URL and get the HTML content
response = requests.get(url)
html = response.content

# Parse the HTML content with Beautiful Soup
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Find the section containing the job reviews
reviews_section = soup.find("div", {"class": "cmp-ReviewsList"})

# Get a list of all the reviews in the section
reviews = reviews_section.find_all("div", {"class": "cmp-Review"})

# Create empty lists to store the review data
titles = []
authors = []
ratings = []
pros = []
cons = []
dates = []

# Loop through the reviews and extract the data
for review in reviews:
    # Get the review title
    title = review.find("a", {"class": "cmp-Review-titleLink"}).text.strip()
    titles.append(title)

    # Get the author name and job title
    author_info = review.find("div", {"class": "cmp-ReviewAuthor"}).text.strip()
    authors.append(author_info)

    # Get the rating
    rating = review.find("div", {"class": "cmp-RatingNumber"}).text.strip()
    ratings.append(rating)

    # Get the pros and cons
    pros_section = review.find("div", {"class": "cmp-ReviewProsCons-prosText"})
    pros_text = pros_section.text.strip() if pros_section else ""
    pros.append(pros_text)

    cons_section = review.find("div", {"class": "cmp-ReviewProsCons-consText"})
    cons_text = cons_section.text.strip() if cons_section else ""
    cons.append(cons_text)

    # Get the review date
    date = review.find("span", {"class": "cmp-ReviewAuthor-subtitle"}).text.strip()
    dates.append(date)

# Create a Pandas DataFrame from the extracted data
data = {"Title": titles, "Author": authors, "Rating": ratings, "Pros": pros, "Cons": cons, "Date": dates}
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <title>Attention Required! | Cloudflare</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" rel="stylesheet"/>
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
# </head>
# <body>
# <div id="cf-wrapper">
# <div class="cf-alert cf-alert-error cf-cookie-error" data-translate="enable_cookies" id="cookie-alert">Please enable cookies.</div>
# <div class="cf-error-details-wrapper" id="cf-error-details">
# <div class="cf-wrapper cf-header cf-error-overview">
# <h1 data-translate="block_headline">Sorry, you have been blocked</h1>
# <h2 class="cf-subheadline"><span data-translate="unable_to_access">You are unable to access</span> indeed.com</h2>
# </div><!-- /.header -->
# <div class="cf-section cf-highlight">
# <div class="cf-wrapper">
# <div class="cf-screenshot-container cf-screenshot-full">
# <span class="cf-no-screenshot error"></span>
# </div>
# </div>
# </div><!-- /.captcha-container -->
# <div class="cf-section cf-wrapper">
# <div class="cf-columns two">
# <div class="cf-column">
# <h2 data-translate="blocked_why_headline">Why have I been blocked?</h2>
# <p data-translate="blocked_why_detail">This website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.</p>
# </div>
# <div class="cf-column">
# <h2 data-translate="blocked_resolve_headline">What can I do to resolve this?</h2>
# <p data-translate="blocked_resolve_detail">You can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.</p>
# </div>
# </div>
# </div><!-- /.section -->
# <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
# <p class="text-13">
# <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">7e727fccfbe21bad</strong></span>
# <span class="cf-footer-separator sm:hidden">•</span>
# <span class="cf-footer-item hidden sm:block sm:mb-1" id="cf-footer-item-ip">
#       Your IP:
#       <button class="cf-footer-ip-reveal-btn" id="cf-footer-ip-reveal" type="button">Click to reveal</button>
# <span class="hidden" id="cf-footer-ip">5.224.29.151</span>
# <span class="cf-footer-separator sm:hidden">•</span>
# </span>
# <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">Cloudflare</a></span>
# </p>
# <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
# </div><!-- /#cf-error-details -->
# </div><!-- /#cf-wrapper -->
# <script>
#   window._cf_translation = {};
#
#
# </script>
# </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14612\1578406900.py in <module>
#      21
#      22 # Get a list of all the reviews in the section
# ---> 23 reviews = reviews_section.find_all("div", {"class": "cmp-Review"})
#      24
#      25 # Create empty lists to store the review data
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ## This works using ScrapflyClient

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import pandas as pd
from scrapfly import ScrapflyClient, ScrapeConfig

client = ScrapflyClient(key="scp-live-25e23c54e25442a181b1acbaf4d02d79")
result = client.scrape(ScrapeConfig(
    url="https://de.indeed.com/cmp/Basf-df1bf734/reviews/toller-arbeitgeber-spannendes-t%C3%A4tigkeitsfeld-gute-verdienstm%C3%B6glichkeiten?id=86016fe1c7d246ac",
    asp=True
    # ^ enable Anti Scraping Protection
))

# %%
print(result.content)
# Out:
# <!DOCTYPE html><html lang="de" dir="ltr"><head><meta charSet="utf-8"/><link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin=""/><link href="https://fonts.googleapis.com/css?family=Noto+Sans:400,400i,700,700i&amp;display=swap" rel="stylesheet"/><script defer="" src="https://d3hbwax96mbv6t.cloudfront.net/turnstile/s/943d9ca/turnstile-compiled.js" crossorigin="anonymous"></script><script defer="" src="/cmp/-/s/assets/70007d9f751f7881/runtime.js" crossorigin="anonymous"></script><script defer="" src="/cmp/-/s/assets/4075c00628c69ee1/vendor.js" crossorigin="anonymous"></script><script defer="" src="/cmp/-/s/assets/33449e244ed200fb/reviews-individual-aurora.js" crossorigin="anonymous"></script><link rel="stylesheet" href="/cmp/-/s/assets/87b3819116a54a61/reviews-individual-aurora.css"/><meta name="description" content="Bewertungen von {1} Arbeitnehmern zu Unternehmenskultur, Gehälter, Sonderleistungen, Work-Life-Balance, Geschäftsleitung, Arbeitsplatzsicherheit und weiteres bei {1}."/><link rel="canonical" href="https://de.indeed.com/cmp/Basf-df1bf734/reviews/toller-arbeitgeber-spannendes-t%C3%A4tigkeitsfeld-gute-verdienstm%C3%B6glichkeiten?id=86016fe1c7d246ac"/><script>window.__JSERROR__=[];window.onerror=function() { window.__JSERROR__.push(arguments)}</script><meta name="viewport" content="width=device-width,initial-scale=1"/><link rel="icon" href="/images/favicon.ico"/><style>/*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */html{line-height:1.15;-webkit-text-size-adjust:100%}body{margin:0}main{display:block}h1{font-size:2em;margin:0.67em 0}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace, monospace;font-size:1em}a{background-color:transparent}abbr[title]{border-bottom:none;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace, monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-0.25em}sup{top:-0.5em}img{border-style:none}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button}button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0}button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:0.35em 0.75em 0.625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{vertical-align:baseline}textarea{overflow:auto}[type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0}[type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto}[type="search"]{-webkit-appearance:textfield;outline-offset:-2px}[type="search"]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details{display:block}summary{display:list-item}template{display:none}[hidden]{display:none}blockquote,dl,dd,h1,h2,h3,h4,h5,h6,hr,figure,p,pre{margin:0}button{background-color:transparent;background-image:none;padding:0}button:focus{outline:1px dotted;outline:5px auto -webkit-focus-ring-color}fieldset{margin:0;padding:0}ol,ul{list-style:none;margin:0;padding:0}html{font-family:system-ui, -apple-system, Segoe UI, Roboto, Ubuntu, Cantarell, Noto Sans, sans-serif, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, "Noto Sans", sans-serif, "Apple Color Emoji", "Segoe UI Emoji", "Segoe UI Symbol", "Noto Color Emoji";line-height:1.5}*,::before,::after{box-sizing:border-box;border-width:0;border-style:solid;border-color:currentColor}hr{border-top-width:1px}img{border-s ...
#         <script>
#             if (window.performance !== undefined && performance.mark !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:start');
#             }
#         </script><link rel="stylesheet" type="text/css" href="https://c03.s3.indeed.com/dist/header/jobseekerHeader.136f5034b9bfd3a88834.css" crossorigin="anonymous">
#
#         <link rel="stylesheet" type="text/css" href="https://c03.s3.indeed.com/fonts/v1/indeedsans.css" crossorigin="anonymous" />
#         <script>
#             if (window.performance !== undefined && performance.mark !== undefined && performance.measure !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:end');
#                 performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#             }
#         </script>
#         <nav class="gnav" id="gnav-main-container" aria-label="Primär">
#             <div data-gnav-region="Main"><style data-emotion="gnav-header 1gheiwz">#gnav-main-container.gnav .gnav-header-1gheiwz{display:flex;box-sizing:border-box;margin:0;min-width:0;width:100%;min-height:3.25rem;background-color:#ffffff;justify-content:space-between;border-bottom-width:0.0625rem;border-bottom-color:#e4e2e0;border-bottom-style:none;}@media screen and (min-width: 62em){#gnav-main-container.gnav .gnav-header-1gheiwz{border-bottom-style:solid;}}</style><div class="gnav-header-1gheiwz e37uo190"><div class="css-wnhbdt e37uo190"><a class="gnav-Logo css-1c21a75 e19afand0" href="https://de.indeed.com?from=gnav-acme--acme-webapp" data-gnav-element-name="Logo" id="indeed-globalnav-logo" aria-label="Indeed-Startseite"><div class="gnav-Logo-icon" aria-hidden="true"><svg width="75" height="20" viewBox="0 0 75 20" fill="none" xmlns="http://www.w3.org/2000/svg" focusable="false" aria-hidden="true"><path fill-rule="evenodd" clip-rule="evenodd" d="M74.613 3.458c-.265-.297-.62-.448-1.1-.448-.48 0-.846.159-1.101.487-.255.317-.387.793-.387 1.417v4.524c-.59-.636-1.203-1.092-1.825-1.399a4.568 4.568 0 0 0-1.356-.397 6.917 6.917 0 0 0-.937-.06c-1.559 0-2.822.536-3.791 1.608-.958 1.072-1.438 2.56-1.438 4.472 0 .904.123 1.747.367 2.52.246.772.59 1.448 1.06 2.022a4.975 4.975 0 0 0 1.67 1.33 4.766 4.766 0 0 0 2.089.465c.345 0 .672-.029.977-.088.205-.03.397-.08.592-.14a5.086 5.086 0 0 0 1.335-.674 7.8 7.8 0 0 0 1.253-1.15v.297c0 .565.143.992.418 1.3.286.297.643.455 1.07.455.438 0 .794-.149 1.07-.435.273-.298.417-.734.417-1.318V4.758c.004-.567-.128-1.004-.383-1.3zm-3.169 12.477c-.275.575-.643 1.002-1.09 1.28-.46.279-.96.416-1.51.416h-.01a2.79 2.79 0 0 1-1.509-.435c-.459-.298-.825-.734-1.089-1.309-.264-.585-.396-1.29-.396-2.123 0-.784.121-1.477.377-2.062.245-.596.601-1.052 1.05-1.368.46-.328.97-.477 1.548-.477h.03c.541 0 1.04.158 1.499.465.459.308.825.756 1.1 1.34.275.585.408 1.29.408 2.102 0 .872-.133 1.597-.408 2.171zm-9.896.13c-.194-.168-.459-.258-.785-.258-.296 0-.52.07-.683.199-.398.356-.713.644-.96.852-.242.199-.52.397-.813.584a3.27 3.27 0 0 1-.896.399 3.798 3.798 0 0 1-1.03.128c-.081 0-.163 0-.235-.01a2.829 2.829 0 0 1-1.303-.397c-.47-.267-.836-.662-1.122-1.179-.275-.536-.418-1.15-.427-1.845h6.145c.825 0 1.466-.12 1.915-.337.46-.239.683-.735.683-1.498 0-.833-.224-1.646-.662-2.45-.438-.795-1.09-1.449-1.976-1.953-.878-.506-1.927-.754-3.16-.754h-.091c-.907.01-1.743.16-2.486.437a5.54 5.54 0 0 0-1.969 1.269 5.677 5.677 0 0 0-1.2 1.994 7.49 7.49 0 0 0-.42 2.518c0 1.925.562 3.432 1.682 4.552 1.06 1.062 2.527 1.618 4.391 1.677.103.01.213.01.327.01.876 0 1.66-.11 2.342-.337.683-.228 1.244-.507 1.694-.843.446-.347.783-.704 1.007-1.07.224-.367.337-.695.337-.963 0-.31-.1-.557-.305-.725zm-7.336-5.605c.5-.526 1.141-.784 1.926-.784h.012c.814 0 1.477.258 1.976.773.5.517.795 1.3.867 2.35h-5.698c.101-1.03.408-1.814.917-2.339zm-6.045 5.346c-.305 0-.529.07-.692.198-.387.357-.713.645-.958.853-.245.198-.51.397-.806.584-.294.179-.591.318-.906.398a3.742 3.742 0 0 1-1.03.128c-.08 0-.162 0-.234-.01a2.841 2.841 0 0 1-1.304-.396 2.932 2.932 0 0 1-1.11-1.18c-.286-.535-.429-1.15-.44-1.844h6.155c.815 0 1.456-.12 1.915-.338.448-.238.674-.734.674-1.497 0-.834-.215-1.647-.653-2.45-.438-.795-1.1-1.45-1.976-1.954-.878-.505-1.937-.753-3.158-.753h-.103c-.906.01-1.731.16-2.486.437a5.383 5.383 0 0 0-1.957 1.268 5.54 5.54 0 0 0-1.212 1.994 7.451 7.451 0 0 0-.42 2.518c0 1.925.572 3.432 1.692 4.552 1.06 1.063 2.517 1.618 4.382 1.677.112.01.212.01.326.01.886 0 1.661-.109 2.343-.336.682-.229 1.244-.507 1.691-.843.46-.348.785-.704 1.01-1.07.223-.367.337-.695.337-.964 0-.307-.103-.555-.296-.723-.202-.17-.469-.26-.784-.26zm-6.562-5.346c.499-.526 1.142-.784 1.927-.784h.011c.814 0 1.477.258 1.976.773.509.517.795 1.3.877 2.35h-5.707c.112-1.03.419-1.814.916-2.339zM6.547 17.969v-7.301c.212.02.417.029.631.029a5.514 5.514 0 0 0 2.792-.744v8.014c0 .685-.163 1.19-.48 1.528-.315.336-.733.504-1.242.504-.5 0-.897-.168-1.223-.515-.315-.336-.478-.842-.478-1.515zm29.6-14.51c-.265-.298-.631-.4 ...
#         </nav>
#     <script>
# "use strict";(()=>{const e=window._INDEED=window._INDEED||{},o=e.shared=e.shared||{};o.v1||(o.v1={load:function(){for(var e=arguments.length,n=new Array(e),r=0;r<e;r++)n[r]=arguments[r];return new Promise(((e,r)=>{o.v1.load.q.push({args:n,resolve:e,reject:r})}))},initialize:e=>{o.v1.config||(o.v1.config=e,n(3))}},o.v1.load.q=[]);const n=e=>{if(o.v1.load.q){var r;const s=o.v1.config;let a=s.loadersUrl;const t=null!==(r=localStorage.getItem("shared-deps.branch"))&&void 0!==r?r:s.branch;t&&(a=a.replace("sharedDepsLoaders",`${t}/sharedDepsLoaders`));const c=document.createElement("script");c.async=!0,c.src=a,c.crossOrigin="anonymous",c.onerror=o=>{if(o instanceof ErrorEvent){const a=e-1;if(a>0)n(a);else{var r;const{error:e,message:n,filename:a,lineno:t,colno:c}=o,d=(null==e?void 0:e.name)||"SharedDepsShimLoaderError",i=(null==e?void 0:e.message)||n||"Failed to fetch & execute sharedDepsLoader",l=(null==e?void 0:e.toString())||`${d}: ${i}`,v=null===(r=(null==e?void 0:e.stack)||`event: ${a}:${t}:${c}\nonerror: ${(new Error).stack}`)||void 0===r?void 0:r.substring(0,1e3),m=document.createElement("script");m.async=!0,m.crossOrigin="anonymous",m.src=`${s.logRoute}&logType=${s.jsErrorLogType}&lth=${s.jsErrorLth}&name=${d}&message=${encodeURIComponent(i)}&toString=${encodeURIComponent(l)}&stack=${encodeURIComponent(v)}`,document.head.appendChild(m)}}},document.head.appendChild(c)}}})();
# window._INDEED.shared.v1.initialize({"publicPath":"https://c03.s3.indeed.com/shared/","loadersUrl":"https://c03.s3.indeed.com/shared/sharedDepsLoadersV1.autoupgrade.js","shareScopes":["react17"],"groups":{"tbt_tst":-1},"logRoute":"https://t.indeed.com/signals/gnav/log?from=acme--acme-webapp-reviews-individual&parentLogId=1h5ctfoqdi93o800&hostAppTk=1h5ctfolqi99o801","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d"});
# </script><script>(() => {
# var callFnWhenReady = window._INDEED && window._INDEED.shared && window._INDEED.shared.v1 ? (fn) => fn() : (fn) => window.addEventListener('onSharedDepsLoadersV1Available', fn, { once: true });
# callFnWhenReady(() => window._INDEED.shared.v1.load("module", {"urls":["https://c03.s3.indeed.com/dist/header/remoteEntry.080b7256826b542c200d.js"],"container":"gnavHeaderModule","module":"./jobseekerHeader","shareScope":"react17","afterEvent":"DOMContentLoaded"}).catch(()=>null));
# })();</script><div id="gnav-script-contents">            <template style='display: none' id='sentry-json' data-json='{&quot;init&quot;:{&quot;dsn&quot;:&quot;https://ecfd85d150d54e4fb18a450d40cff53a@sentry.indeed.com/49991&quot;,&quot;release&quot;:&quot;64c001ef50ceee55c2b6aa069749bf19b8f38e04&quot;},&quot;isEnabled&quot;:true,&quot;tags&quot;:{&quot;appName&quot;:&quot;acme--acme-webapp&quot;},&quot;ctk&quot;:&quot;1h5ctfolnj9jp801&quot;}'></template>
#             <script>
#             window.IndeedSentry = window.IndeedSentry || {};
#             window.IndeedSentry.preInitErrors = [];
#             window.IndeedSentry.preInitErrorCatcher = function (error) {
#                 window.IndeedSentry.preInitErrors.push(error);
#             };
#             window.addEventListener("error", window.IndeedSentry.preInitErrorCatcher);
#             </script>
#             <script>(() => {
# var callFnWhenReady = window._INDEED && window._INDEED.shared && window._INDEED.shared.v1 ? (fn) => fn() : (fn) => window.addEventListener('onSharedDepsLoadersV1Available', fn, { once: true });
# callFnWhenReady(() => window._INDEED.shared.v1.load("js", {"urls":["https://c03.s3.indeed.com/frontend-sentry-bundle/v1.1.2/js/sentry.js?2"],"afterEvent":"DOMContentLoaded"}).catch(()=>null));
# })();</script><script src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/2fc180c65051a617f27565b17f4935f8/indeed/consent/0d4d9047-e9bb-46ba-b003-a0bd1f4a7d4f/OtAutoBlock.js" crossorigin="anonymous"></script><script defer="true" data-domain-name="indeed.com" data-domain-script="0d4d9047-e9bb-46ba-b003-a0bd1f4a7d4f" data-language="de" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/2fc180c65051a617f27565b17f4935f8/indeed/scripttemplates/otSDKStub.js" data-ignore-geolocation="true" crossorigin="anonymous"></script>
#         <script>
#             window.signals_transport = window.signals_transport || {
#                 emitSignal: function(data){
#                     window.signals_transport_tmp = window.signals_transport_tmp || [];
#                     if (window.signals_transport_tmp.length < 1000) {
#                         window.signals_transport_tmp.push(data);
#                     }
#                 }
#             };
#         </script>
#     </div></div><div id="cmp-container"><div><style data-emotion="css u74ql7">.css-u74ql7{box-sizing:border-box;margin-block-start:0;margin-block-end:0;-webkit-margin-start:0;margin-inline-start:0;-webkit-margin-end:0;margin-inline-end:0;min-inline-size:0;}</style><div itemscope="" itemType="http://schema.org/LocalBusiness" class="dd-privacy-allow css-u74ql7 eu4oa1w0"><header data-tn-section="header" class="css-1vcnma3 eu4oa1w0"><div style="background-color:rgba(255, 255, 255, 1)" class="css-1kv6zkn e37uo190"><style data-emotion="css 1wzzkim">.css-1wzzkim{box-sizing:border-box;margin-block-start:0;margin-block-end:0;-webkit-margin-start:0;margin-inline-start:0;-webkit-margin-end:0;margin-inline-end:0;min-inline-size:0;position:relative;width:960px;max-height:200px;min-height:64px;height:20vw;-webkit-background-position:center center;background-position:center center;-webkit-background-size:cover;background-size:cover;background-repeat:no-repeat;border-bottom-left-radius:8px;border-bottom-right-radius:8px;background-image:url('https://d2q79iu7y748jz.cloudfront.net/s/_headerimage/980x200/1a2d908d59f385bb3541ec493518fa21');}@media (-webkit-min-device-pixel-ratio: 2),(min--moz-device-pixel-ratio: 2),(-o-min-device-pixel-ratio: 2/1),(min-device-pixel-ratio: 2),(min-resolution: 192dpi),(min-resolution: 2dppx){.css-1wzzkim{background-image:url('https://d2q79iu7y748jz.cloudfront.net/s/_headerimage/1960x400/1a2d908d59f385bb3541ec493518fa21');}}</style><div role="img" aria-hidden="true" data-testid="cmp-CoverImage" class="css-1wzzkim eu4oa1w0"></div></div><div class="css-14x0tgq eu4oa1w0"><div style="background-color:rgba(255, 255, 255, 1)" class="css-660jx2 eu4oa1w0"></div><div class="css-1pdmn07 eu4oa1w0"></div><div class="css-u74ql7 eu4oa1w0"><div class="css-ba9377 eu4oa1w0"><div data-tn-component="cmp-HeaderLayout" data-test-style="standard" class="css-5je64a eu4oa1w0"><div class="css-ohrj1l eu4oa1w0"><div class="css-1i5bjam eu4oa1w0"><div class="css-cfhwfm eu4oa1w0"><div class="css-bitz2j eu4oa1w0"><div class="css-1wtws2j eu4oa1w0"><div class="css-1oe275d e37uo190"><img itemProp="image" src="https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/64x64/5652c32adeba30502c048c2c9d36b35a" srcSet="https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/64x64/5652c32adeba30502c048c2c9d36b35a 1x, https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/128x128/5652c32adeba30502c048c2c9d36b35a 2x" style="flex:0 0 auto;max-width:100%;max-height:100%" alt="" aria-hidden="true"/></div></div></div><div style="-ms-flex-preferred-size:800px" class="css-yu5l5a e37uo190"><div class="css-5lduno e37uo190"><div><div itemProp="name" class="css-19rjr9w e1wnkr790">BASF</div></div></div><div class="css-1uyfi54 e37uo190"><div class="css-1bxh0bx e37uo190"><span class="css-1vlfpkl e1wnkr790">4,1 von 5 Sternen.</span><span aria-hidden="true" class="css-htn3vt e1wnkr790">4,1</span><div class="css-8ikdl0 eu4oa1w0"><div role="presentation"><div style="background-image:url(&quot;/cmp/-/s/assets/b0c3663fb1a3ba0d/unfilled-stars.svg&quot;)" class="css-1ycs1oe eu4oa1w0"><div data-testid="filledStar" style="width:67.8144px;background-image:url(&quot;/cmp/-/s/assets/2edabdc9de66ebd4/filled-stars.svg&quot;)" class="css-192xu93 eu4oa1w0"></div></div></div></div><div><a href="/cmp/Basf-df1bf734/reviews" data-tn-element="reviews-countLink" data-tn-link="true" class="css-11lxsfp e19afand0">3.480 Bewertungen</a></div></div></div></div></div><div class="css-1t78yay eu4oa1w0"><div class="css-1avzywx e37uo190"><div class="css-3jwk01 eu4oa1w0"><div class="css-1slwpw3 eu4oa1w0"><div class="css-ty33xs eu4oa1w0"><style data-emotion="css 1pbg2x">.css-1pbg2x{box-sizing:border-box;background:none;-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;text-align:start;-webkit-text-decoration:none;text-decoration:none;border:none;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-align-items:center;-webkit-box-align ...
#                     window._initialData = JSON.parse(document.getElementById('comp-initialData').textContent)
#                     window['indeed.i18n.localeData'] = JSON.parse(document.getElementById('comp-translationData').textContent)
#                 </script><div class="cmp-external dd-privacy-mask"><script id="_indeed_gnav_footer_config" type="application/json">{"footerVariant":"DESKTOP_JOBSEEKER_FOOTER","desktopJobseekerFooterConfig":{"links":[{"description":"Hiring Lab","href":"https://www.hiringlab.org/de/","dataHref":"https://www.hiringlab.org/de/?from=gnav-acme--acme-webapp","dataGnavElementName":"HiringLab"},{"description":"Karriere-Guide","href":"https://de.indeed.com/karriere-guide","dataHref":"https://de.indeed.com/karriere-guide?from=gnav-acme--acme-webapp\u0026ikw=jsfooter\u0026isid=jasx_us-en","dataGnavElementName":"CareerAdvice"},{"description":"Jobs durchsuchen","href":"https://de.indeed.com/browsejobs","dataHref":"https://de.indeed.com/browsejobs?from=gnav-acme--acme-webapp","dataGnavElementName":"BrowseJobs"},{"description":"Gehalt","href":"https://de.indeed.com/career/salaries","dataHref":"https://de.indeed.com/career/salaries?from=gnav-acme--acme-webapp","dataGnavElementName":"Salaries"},{"description":"Indeed Events","href":"https://www.indeedevents.com/de-de","dataHref":"https://www.indeedevents.com/de-de?from=gnav-acme--acme-webapp","dataGnavElementName":"IndeedEvents"},{"description":"Karriere bei Indeed","href":"https://de.indeed.com/cmp/indeed/about","dataHref":"https://de.indeed.com/cmp/indeed/about?from=gnav-acme--acme-webapp","dataGnavElementName":"WorkAtIndeed"},{"description":"Länder","href":"https://de.indeed.com/worldwide","dataHref":"https://de.indeed.com/worldwide?from=gnav-acme--acme-webapp","dataGnavElementName":"Countries"},{"description":"Über uns","href":"https://de.indeed.com/about","dataHref":"https://de.indeed.com/about?from=gnav-acme--acme-webapp","dataGnavElementName":"About"},{"description":"Impressum","href":"https://de.indeed.com/about/our-company","dataHref":"https://de.indeed.com/about/our-company?from=gnav-acme--acme-webapp","dataGnavElementName":"CompanyInfo"},{"description":"Indeed-Hilfebereich","href":"https://support.indeed.com/hc/de?redirect=false","dataHref":"https://support.indeed.com/hc/de?redirect=false\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"JobseekerHelpCenter"}],"impressumLinks":[{"description":"Barrierefreiheit bei Indeed","href":"https://de.indeed.com/accessibility?hl=de","dataHref":"https://de.indeed.com/accessibility?hl=de\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"Accessibility"},{"description":"Datenschutzzentrum","href":"https://hrtechprivacy.com/de","dataHref":"https://hrtechprivacy.com/de?from=gnav-acme--acme-webapp","dataGnavElementName":"PrivacyCenter"},{"description":"Cookies","href":"https://hrtechprivacy.com/de/brands/about-indeed#Cookies","dataHref":"https://hrtechprivacy.com/de/brands/about-indeed?from=gnav-acme--acme-webapp#Cookies","dataGnavElementName":"Cookies"},{"description":"Datenschutzerklärung","href":"https://hrtechprivacy.com/de/brands/about-indeed#privacypolicy","dataHref":"https://hrtechprivacy.com/de/brands/about-indeed?from=gnav-acme--acme-webapp#privacypolicy","dataGnavElementName":"Privacy"}],"legalLink":{"description":"Nutzungsbedingungen","href":"https://de.indeed.com/legal?hl=de","dataHref":"https://de.indeed.com/legal?hl=de\u0026from=gnav-acme--acme-webapp","dataGnavElementName":"Terms"},"year":2023},"logRoute":"https://t.indeed.com/signals/gnav/log?from=acme--acme-webapp-reviews-individual\u0026parentLogId=1h5ctfoqdi93o800\u0026hostAppTk=1h5ctfolqi99o801","signalsLogRoute":"https://t.indeed.com/signals/v1/log?from=acme--acme-webapp-reviews-individual\u0026parentLogId=1h5ctfoqdi93o800\u0026hostAppTk=1h5ctfolqi99o801","serviceRequestLogUID":"1h5ctfoqdi93o800","hostAppTk":"1h5ctfolqi99o801","pageId":"reviews-individual","canonicalPageId":"","applicationId":"acme--acme-webapp","appName":"acme--acme-webapp","country":"DE","requestURL":"https://de.indeed.com/cmp/Basf-df1bf734/reviews/toller-arbeitgeber-spannendes-t%C3%A4tigkeitsfeld-gute-verdienstm%C3%B6glichkeiten","language":"de","isMobile":false,"jsErrorLogType":"gnavJSError","jsE ...
#         <script>
#             if (window.performance !== undefined && performance.mark !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSFooter:start');
#             }
#         </script><link rel="stylesheet" type="text/css" href="https://c03.s3.indeed.com/dist/footer/jobseekerDesktopFooter.a759dc9627c457c8b794.css" crossorigin="anonymous">
#
#         <link rel="stylesheet" type="text/css" href="https://c03.s3.indeed.com/fonts/v1/indeedsans.css" crossorigin="anonymous" />
#         <script>
#             if (window.performance !== undefined && performance.mark !== undefined && performance.measure !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSFooter:end');
#                 performance.measure('gnavRenderBlockingCSSFooter', 'gnavRenderBlockingCSSFooter:start', 'gnavRenderBlockingCSSFooter:end');
#             }
#         </script><div class="gnav gnav-reset" id="gnav-footer-container"><div class="main" data-gnav-region="MainFooter" data-reactroot=""><footer class="icl-GlobalFooter" role="contentinfo"><div class="icl-GlobalFooter-nav"><ul class="icl-GlobalFooter-items"><li class="icl-GlobalFooter-item"><a data-gnav-element-name="HiringLab" class="icl-GlobalFooter-link" href="https://www.hiringlab.org/de/">Hiring Lab</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="CareerAdvice" class="icl-GlobalFooter-link" href="https://de.indeed.com/karriere-guide">Karriere-Guide</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="BrowseJobs" class="icl-GlobalFooter-link" href="https://de.indeed.com/browsejobs">Jobs durchsuchen</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="Salaries" class="icl-GlobalFooter-link" href="https://de.indeed.com/career/salaries">Gehalt</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="IndeedEvents" class="icl-GlobalFooter-link" href="https://www.indeedevents.com/de-de">Indeed Events</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="WorkAtIndeed" class="icl-GlobalFooter-link" href="https://de.indeed.com/cmp/indeed/about">Karriere bei Indeed</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="Countries" class="icl-GlobalFooter-link" href="https://de.indeed.com/worldwide">Länder</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="About" class="icl-GlobalFooter-link" href="https://de.indeed.com/about">Über uns</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="CompanyInfo" class="icl-GlobalFooter-link" href="https://de.indeed.com/about/our-company">Impressum</a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="JobseekerHelpCenter" class="icl-GlobalFooter-link" href="https://support.indeed.com/hc/de?redirect=false">Indeed-Hilfebereich</a></li></ul><ul class="icl-GlobalFooter-items"><li class="icl-GlobalFooter-item">© 2023 Indeed</li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="Accessibility" class="icl-GlobalFooter-link" href="https://de.indeed.com/accessibility?hl=de">Barrierefreiheit bei Indeed<!-- --> </a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="PrivacyCenter" class="icl-GlobalFooter-link" href="https://hrtechprivacy.com/de">Datenschutzzentrum<!-- --> </a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="Cookies" class="icl-GlobalFooter-link" href="https://hrtechprivacy.com/de/brands/about-indeed#Cookies">Cookies<!-- --> </a></li><li class="icl-GlobalFooter-item"><a data-gnav-element-name="Privacy" class="icl-GlobalFooter-link" href="https://hrtechprivacy.com/de/brands/about-indeed#privacypolicy">Datenschutzerklärung<!-- --> </a></li><li class="icl-GlobalFooter-item"><a data-href="https://de.indeed.com/legal?hl=de&amp;from=gnav-acme--acme-webapp" data-gnav-element-name="Terms" class="icl-GlobalFooter-link" href="https://de.indeed.com/legal?hl=de">Nutzungsbedingungen</a></li></ul></div></footer></div></div><script>(() => {
# var callFnWhenReady = window._INDEED && window._INDEED.shared && window._INDEED.shared.v1 ? (fn) => fn() : (fn) => window.addEventListener('onSharedDepsLoadersV1Available', fn, { once: true });
# callFnWhenReady(() => window._INDEED.shared.v1.load("module", {"urls":["https://c03.s3.indeed.com/dist/footer/remoteEntry.61e00713e5d7b71d98f8.js"],"container":"gnavFooterModule","module":"./jobseekerDesktopFooter","shareScope":"react17","afterEvent":"DOMContentLoaded"}).catch(()=>null));
# })();</script></div><script>
#             window.addEventListener('load', function(event) {
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5BCKBTQ');
#             });
#    </script><script>PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
#             PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 1, 'acmeTest', 'true', 3];</script><script>PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];</script><script>
#             window.addEventListener('load', function(e) {
#                 ["https://www.googletagmanager.com/gtag/js?id=DC-8232301"]
#                     .forEach(function(p) { var s = document.createElement('script'); s.src = p; document.body.appendChild(s); })
#             });
#             window.dataLayer = window.dataLayer || [];
#             function gtag(){dataLayer.push(arguments);}
#             gtag('js', new Date());
#             gtag('config', 'DC-8232301');
#         </script><script>
#             window.addEventListener("load", function(event) {
#                 var ga_domains = [];
#                 ga_domains.push('indeed.co.in');
# ga_domains.push('indeed.lu');
# ga_domains.push('indeed.fr');
# ga_domains.push('indeed.com.br');
# ga_domains.push('indeed.de');
# ga_domains.push('indeed.co.uk');
# ga_domains.push('indeed.hk');
# ga_domains.push('indeed.fi');
# ga_domains.push('indeed.pt');
# ga_domains.push('indeed.jp');
# ga_domains.push('indeed.com');
# ga_domains.push('indeed.com.sg');
# ga_domains.push('indeed.nl');
# ga_domains.push('indeed.com.pk');
# ga_domains.push('indeed.cl');
# ga_domains.push('indeed.es');
# ga_domains.push('indeed.co.ve');
# ga_domains.push('indeed.com.mx');
# ga_domains.push('indeed.ae');
# ga_domains.push('indeed.ch');
# ga_domains.push('indeed.com.co');
# ga_domains.push('indeed.com.my');
# ga_domains.push('indeed.com.ph');
# ga_domains.push('indeed.co.za');
# ga_domains.push('indeed.ie');
# ga_domains.push('indeed.com.au');
# ga_domains.push('indeed.ca');
# ga_domains.push('indeed.com.pe');
#                 (function (i, s, o, g, r, a, m) {
#                     i['GoogleAnalyticsObject'] = r;
#                     i[r] = i[r] || function () {
#                         (i[r].q = i[r].q || []).push(arguments)
#                     }, i[r].l = 1 * new Date();
#                     a = s.createElement(o),
#                             m = s.getElementsByTagName(o)[0];
#                     a.async = 1;
#                     a.src = g;
#                     m.parentNode.insertBefore(a, m)
#                 })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#                 ga('create', 'UA-90780-1', 'auto', {
#                     'allowLinker': true
#                 });
#                 ga('require', 'linkid');
#                 ga('require', 'linker');
#                 ga('linker:autoLink', ga_domains, false, true);
#                 ga('require', 'displayfeatures');
#                 ga('send', 'pageview');
#
#                 // set any variables so when the page is logged variables are included
#                 (function () {
#                     if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
#                         for (var i in PENDING_ANALYTICS_VARS) {
#                             ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
#                         }
#                     }
#                 })();
#             });
#           </script><script>
#             window.addEventListener("load", function(event) {
#                 window._comscore = window._comscore || [];
#                 window._comscore.push({ c1: "2", c2: "6486505", c4:"de.indeed.com/cmp/Basf-df1bf734/reviews/toller-arbeitgeber-spannendes-t%C3%A4tigkeitsfeld-gute-verdienstm%C3%B6glichkeiten", c15:"1h5ctfolnj9jp801" });
#                 (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#             });
#         </script><noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=de.indeed.com%2Fcmp%2FBasf-df1bf734%2Freviews%2Ftoller-arbeitgeber-spannendes-t%25C3%25A4tigkeitsfeld-gute-verdienstm%25C3%25B6glichkeiten&amp;c15=1h5ctfolnj9jp801&amp;cv=2.0&amp;cj=1" style="display:none" width="0" height="0" alt=""/></noscript><script>(function(){var js = "window['__CF$cv$params']={r:'7e72843dbfb035ed',m:'pne6m3h1nYX8a5prdgRV3DYh.gQmhBDLpzSy0RbvXkQ-1689429468-0-AY10KSD1nOFpCaH+oeUFHmiRfKLGtoM57QimboJUkeZe'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body></html>

# %%
# Send a request to the URL and get the HTML content
response = result
html = response.content
# Parse the HTML content with Beautiful Soup
soup = BeautifulSoup(html, "html.parser")
#print(soup)
# Find the section containing the job reviews
reviews_section = soup.find("h1", {"class": "css-w9nrpr e1tiznh50"}).text.strip()
print(reviews_section)
titelofreview = soup.find("span", {"data-testid": "titleSpan"}).text.strip()
print(titelofreview)
reviewbody = soup.find("span", {"class": "css-82l4gy eu4oa1w0"}).text.strip()
print(reviewbody)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14612\2827292380.py in <module>
#       6 #print(soup)
#       7 # Find the section containing the job reviews
# ----> 8 reviews_section = soup.find("h1", {"class": "css-w9nrpr e1tiznh50"}).text.strip()
#       9 print(reviews_section)
#      10 titelofreview = soup.find("span", {"data-testid": "titleSpan"}).text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
## other try, dosent work

# %%
reviews = reviews_section.find_all("div", {"class": "cmp-Review"})

# Create empty lists to store the review data
titles = []
authors = []
ratings = []
pros = []
cons = []
dates = []

# Loop through the reviews and extract the data
for review in reviews:
    # Get the review title
    title = review.find("a", {"class": "cmp-Review-titleLink"}).text.strip()
    titles.append(title)

    # Get the author name and job title
    author_info = review.find("div", {"class": "cmp-ReviewAuthor"}).text.strip()
    authors.append(author_info)

    # Get the rating
    rating = review.find("div", {"class": "cmp-RatingNumber"}).text.strip()
    ratings.append(rating)

    # Get the pros and cons
    pros_section = review.find("div", {"class": "cmp-ReviewProsCons-prosText"})
    pros_text = pros_section.text.strip() if pros_section else ""
    pros.append(pros_text)

    cons_section = review.find("div", {"class": "cmp-ReviewProsCons-consText"})
    cons_text = cons_section.text.strip() if cons_section else ""
    cons.append(cons_text)

    # Get the review date
    date = review.find("span", {"class": "cmp-ReviewAuthor-subtitle"}).text.strip()
    dates.append(date)

# Create a Pandas DataFrame from the extracted data
data = {"Title": titles, "Author": authors, "Rating": ratings, "Pros": pros, "Cons": cons, "Date": dates}
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14612\36759086.py in <module>
# ----> 1 reviews = reviews_section.find_all("div", {"class": "cmp-Review"})
#       2
#       3 # Create empty lists to store the review data
#       4 titles = []
#       5 authors = []
#
# NameError: name 'reviews_section' is not defined

# %%
import pandas as pd

df1 = pd.DataFrame({'review_title': [],'review':[],'author':[],'rating':[]})
page=response
soup = BeautifulSoup(page.content, 'lxml')
results2 = soup.find("div",{ "id" : 'cmp-container'})
elems = results.find_all(class_='cmp-Review-container')
for elem in elems:
    title = elem.find(attrs = {'class':'cmp-Review-title'})
    review = elem.find('div', {'class': 'cmp-Review-text'})
    print(review)
    author = elem.find(attrs = {'class':'cmp-Review-author'})
    rating = elem.find(attrs = {'class':'cmp-ReviewRating-text'})
    df1 = df1.append({'review_title': title.text,
    'review': review.text,
    'author': author.text,
    'rating': rating.text
    }, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 df1 = pd.DataFrame({'review_title': [],'review':[],'author':[],'rating':[]})
# ----> 4 page=response
#       5 soup = BeautifulSoup(page.content, 'lxml')
#       6 results2 = soup.find("div",{ "id" : 'cmp-container'})
#
# NameError: name 'response' is not defined

# %%
elems

# %%
import requests
import json

api_url = 'https://www.page2api.com/api/v1/scrape'
payload = {
"api_key": "c3de64f1c1497dfeb34079abde7b28b72c65ed85",
"premium_proxy": "us",
"real_browser": True,
"javascript": False,
"batch": {
"urls": "https://www.glassdoor.de/Bewertungen/BASF-Bewertungen-E4231_P[1, 25, 1,10].htm",
"concurrency": 1,
"merge_results": True
},
"parse": {
"reviews": [
{
"_parent": "div.gdReview",
"title": "a.reviewLink >> text",
"author_info": "[class*=newUiJobLine] .middle >> text",
"rating": "span.ratingNumber >> text",
"pros": "span[data-test=pros] >> text",
"cons": "span[data-test=cons] >> text",
"helpful": "div.common__EiReviewDetailsStyle__socialHelpfulcontainer >> text"
}
]
}
}

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
response = requests.post(api_url, data=json.dumps(payload), headers=headers)
result = json.loads(response.text)

# %%
print(result)
# Out:
# <Response [400]>

# %%
import pandas as pd
df111 = pd.DataFrame(result['result']['reviews'], columns=['title', 'author_info', 'rating', 'pros', 'cons'])
df111
# Out:
# Empty DataFrame
# Columns: [title, author_info, rating, pros, cons]
# Index: []
